# %% [markdown]
# # Imports

# %%
from utils import ixbrl_frs_102_2024
from bs4 import BeautifulSoup
from document_retrieval import *
import re

# %% [markdown]
# # Functions

# %%
def retrieve_all_ix_financial_data_minus(xhtml_content_path):
    """
    Retrieve financial values from the XHTML content, including detecting negative values and adjusting for decimals.
    
    Args:
        xhtml_content_path (str): The path to the XHTML file.
    
    Returns:
        dict: A dictionary containing the financial values.
    """

    # Open the XHTML file in read mode with UTF-8 encoding
    with open(xhtml_content_path, 'r', encoding='utf-8') as file:
        # Read the entire content of the file into a string variable
        xhtml_content = file.read()

    # Parse the XHTML content using BeautifulSoup with 'html.parser' to create a soup object
    soup = BeautifulSoup(xhtml_content, 'html.parser')
    
    # Initialize an empty dictionary to store the financial values
    dict_name = {}

    # Iterate over each label in the ixbrl_labels_2024_full list
    for label in ixbrl_frs_102_2024:
        
        # Check if the label is not empty or None
        if label:
            print(f'label: {label}')
            # Select all elements in the soup that have a 'name' attribute ending with the current label
            # elements = soup.select(f'[name$="{label}"]')
            elements = soup.select(f'[name$=":{label}"]')
            # Initialize an empty list to temporarily store the values for the current label
            temp_list = []
            # Iterate over each element found
            for item in elements:
                print(f'item: {item}')
                # Extract and strip the text content of the element
                value = item.text.strip()
                # Check if the element has a 'sign' attribute and if its value is '-'
                if item.has_attr('sign') and item['sign'] == '-':
                    # Prepend a '-' to the value to indicate it is negative
                    value = '-' + value
                
                # Check if the element has a 'decimals' attribute and if its value is '-3'
                if item.has_attr('decimals') and item['decimals'] == '-3':
                    # Convert the value to an integer (removing commas), multiply by 1000, and format with commas
                    # This is because '-3' means they simplify the reporting and values need to be multiplied by 1000
                    value = '{:,}'.format(int(value.replace(',', '')) * 1000)
                
                # Append the processed value to the temporary list
                temp_list.append(value)
                print(f'temp list: {temp_list}')

            # Assign the temporary list to the dictionary with the current label as the key
            dict_name[label] = temp_list

    # Return the dictionary containing all the financial values
    return dict_name

# %% [markdown]
# ### Micro, Small or Medium selecting criteria

# %% [markdown]
# Data obtaine from:
# https://www.gov.uk/government/publications/life-of-a-company-annual-requirements/life-of-a-company-part-1-accounts
#
# Micro companies
# - a turnover of £632,000 or less
# - £316,000 or less on its balance sheet
# - 10 employees or less
#
#
# Qualifying as a small company
# For accounting periods beginning on or after 1 January 2016, a small company must meet at least 2 of the following conditions:
#
# - annual turnover must be not more than £10.2 million
# - the balance sheet total must be not more than £5.1 million
# - the average number of employees must be not more than 50
#
# Qualifying as a medium-sized company
# To be a medium-sized company, you must meet at least 2 of the following conditions:
#
# - the annual turnover must be no more than £36 million
# - the balance sheet total must be no more than £18 million
# - the average number of employees must be no more than 250

# %% [markdown]
# #### company_size() Function
#
# This function determines the size of a company based on the UK Company House criteria by retrieving and processing relevant ixbrl labels from an XHTML file. The function follows these steps:
#
# 1. **Define Criteria**: It defines the criteria for different company sizes (micro, small, medium) based on turnover, balance sheet total, and number of employees.
#
# 2. **Retrieve ixbrl Data**: It retrieves financial data from the XHTML file using the `retrieve_all_ix_financial_data_minus` function.
#
# 3. **Extract Data**: It extracts the required data (turnover, fixed assets, current assets, employees) from the retrieved ixbrl data.
#
# 4. **Handle Missing Data**:
#    - **Turnover**: If turnover data is missing, it attempts to retrieve it directly from the XHTML content by searching for specific tags.
#    - **Fixed Assets**: If fixed assets data is missing, it calculates the value by aggregating values from its subcomponents.
#    - **Current Assets**: If current assets data is missing, it calculates the value by aggregating values from its subcomponents.
#    - **Employees**: If employee data is missing, it logs a message.
#
# 5. **Convert Data**: It converts the extracted string values to integers for numerical processing.
#
# 6. **Calculate Balance Sheet**: It calculates the total balance sheet value for the latest and previous year by summing fixed and current assets.
#
# 7. **Format Data**: It formats the numerical values with commas for human readability.
#
# 8. **Determine Company Size**: It determines the size of the company by checking if it meets at least 2 out of 3 conditions for each size category (micro, small, medium). If none of these conditions are met, the company is classified as large.
#
# The function also includes detailed logging to help trace the steps and identify any issues during execution.

# %%
def company_size(file_path):
    """
    Determine the size of a company based on the UK Company House criteria.

    Args:
        file_path (str): The path to the XHTML file.

    Returns:
        str: The size of the company ('micro', 'small', 'medium', or 'large').
    """
    # Define the criteria for different company sizes
    micro_criteria = {
        'turnover': 632000,
        'balance_sheet': 316000,
        'employees': 10
    }
    small_criteria = {
        'turnover': 10200000,
        'balance_sheet': 5100000,
        'employees': 50
    }
    medium_criteria = {
        'turnover': 36000000,
        'balance_sheet': 18000000,
        'employees': 250
    }

    # Retrieve ixbrl data from the XHTML file
    ixbrl_data = retrieve_all_ix_financial_data_minus(file_path)

    # Extract the required data from the ixbrl_data dictionary
    turnover = ixbrl_data.get('TurnoverRevenue', [])
    fixed_assets = ixbrl_data.get('FixedAssets', [])
    current_assets = ixbrl_data.get('CurrentAssets', [])
    employees = ixbrl_data.get('AverageNumberEmployeesDuringPeriod', [])

    # Check if any of the ixbrl labels values list is empty and display a message
    if not turnover:
        print("TurnoverRevenue list is empty.")
        # Retrieve turnover values from the XHTML content if not present in ixbrl_data
        with open(file_path, 'r') as file:
            content = file.read()
            print(f'attempting to match Turnover')
            
            # Find the tag containing 'Turnover' or 'turnover'
            turnover_start = re.search(r'<div[^>]*>Turnover</div>|<div[^>]*>turnover</div>', content, re.IGNORECASE)
            if turnover_start:
                print(f"Found 'Turnover' tag")
                # Get the content after the 'Turnover' tag
                content_after_turnover = content[turnover_start.end():]
                
                # Find the next monetary values, excluding single digits other than zero
                turnover_values = re.findall(r'>(\d{2,}|\d{1,3}(?:,\d{3})+)</div>', content_after_turnover)
                if turnover_values:
                    turnover = [value.replace(',', '') for value in turnover_values[:2]]
                    print(f"Turnover values retrieved from XHTML content: {turnover}")
                else:
                    print("Could not find valid monetary values after 'Turnover' tag")
            else:
                print("Could not find 'Turnover' tag")

    if not fixed_assets:
        print("FixedAssets list is empty.")
    if not current_assets:
        print("CurrentAssets list is empty.")
    if not employees:
        print("AverageNumberEmployeesDuringPeriod list is empty.")

    # Convert string values to integers after removing commas
    turnover = [int(value.replace(',', '')) for value in turnover]
    employees = [int(value.replace(',', '')) for value in employees]

    # Calculate fixed assets if it's empty
    if not fixed_assets:
        fixed_assets_components = [
            'IntangibleAssets',
            'PropertyPlantEquipment',
            'InvestmentFixedAssets',
            'InvestmentProperty',
            'BiologicalAssetsNon-current'
        ]
        
        fixed_assets = [0, 0]  # Initialize with two zeros for the last two years
        for component in fixed_assets_components:
            component_values = ixbrl_data.get(component, [])
            if component_values:
                for i, value in enumerate(component_values[:2]):  # Use only the first two items that generally represent the total sum of the subcomponents
                    try:
                        int_value = int(value.replace(',', ''))
                        fixed_assets[i] += int_value
                    except ValueError:
                        print(f"ValueError: invalid literal for int() with base 10: '{value}' in label '{component}'")
        
        # Calculate 'InvestmentFixedAssets' if it's empty
        if not ixbrl_data.get('InvestmentFixedAssets', []):
            investment_fixed_assets_components = [
                'InvestmentsInGroupUndertakings',
                'LoansToGroupUndertakings',
                'InvestmentsInAssociatesJointVenturesParticipatingInterests',
                'LoansToAssociatesJointVenturesParticipatingInterests',
                'OtherInvestmentsOtherThanLoans',
                'OtherLoansClassifiedUnderInvestments',
                'OwnShares'
            ]
            investment_fixed_assets = [0, 0]  # Initialize with two zeros for the last two years
            for component in investment_fixed_assets_components:
                component_values = ixbrl_data.get(component, [])
                if component_values:
                    for i, value in enumerate(component_values[:2]):  # Use only the first two items that generally represent the total sum of the subcomponents
                        try:
                            int_value = int(value.replace(',', ''))
                            investment_fixed_assets[i] += int_value
                        except ValueError:
                            print(f"ValueError: invalid literal for int() with base 10: '{value}' in label '{component}'")
            fixed_assets = [fa + ifa for fa, ifa in zip(fixed_assets, investment_fixed_assets)]
            print("Investment Fixed Assets value was missing and calculated using components.")
        print("Fixed Assets value was missing and calculated using components.")
    else:
        fixed_assets = [int(value.replace(',', '')) for value in fixed_assets[:2]]  # Use only the first two items

    # Calculate current assets if it's empty
    if not current_assets:
        current_assets_components = [
            'TotalInventories',
            'BiologicalAssetsCurrent',
            'Debtors',
            'CurrentAssetInvestments',
            'CashBankOnHand'
        ]
        
        current_assets = [0, 0]  # Initialize with two zeros for the last two years
        for component in current_assets_components:
            component_values = ixbrl_data.get(component, [])
            if component_values:
                for i, value in enumerate(component_values[:2]):  # Use only the first two items that generally represent the total sum of the subcomponents
                    try:
                        int_value = int(value.replace(',', ''))
                        current_assets[i] += int_value
                    except ValueError:
                        print(f"ValueError: invalid literal for int() with base 10: '{value}' in label '{component}'")
        
        # Calculate 'Debtors' if it's empty
        if not ixbrl_data.get('Debtors', []):
            debtors_components = [
                'TradeDebtorsTradeReceivables',
                'AmountsOwedByGroupUndertakings',
                'AmountsOwedByAssociatesJointVenturesParticipatingInterests',
                'OtherDebtorsBalanceSheetSubtotal',
                'CalledUpShareCapitalNotPaidCurrentAsset',
                'PrepaymentsAccruedIncome',
                'DeferredTaxAssetDebtors'
            ]
            debtors = [0, 0]  # Initialize with two zeros for the last two years
            for component in debtors_components:
                component_values = ixbrl_data.get(component, [])
                if component_values:
                    for i, value in enumerate(component_values[:2]):  # Use only the first two items that generally represent the total sum of the subcomponents
                        try:
                            int_value = int(value.replace(',', ''))
                            debtors[i] += int_value
                        except ValueError:
                            print(f"ValueError: invalid literal for int() with base 10: '{value}' in label '{component}'")
            current_assets = [ca + d for ca, d in zip(current_assets, debtors)]
            print("Debtors value was missing and calculated using components.")
        
        # Calculate 'CurrentAssetInvestments' if it's empty
        if not ixbrl_data.get('CurrentAssetInvestments', []):
            current_asset_investments_components = [
                'InvestmentsInGroupUndertakings',
                'OwnShares',
                'OtherCurrentAssetInvestmentsBalanceSheetSubtotal'
            ]
            current_asset_investments = [0, 0]  # Initialize with two zeros for the last two years
            for component in current_asset_investments_components:
                component_values = ixbrl_data.get(component, [])
                if component_values:
                    for i, value in enumerate(component_values[:2]):  # Use only the first two items that generally represent the total sum of the subcomponents
                        try:
                            int_value = int(value.replace(',', ''))
                            current_asset_investments[i] += int_value
                        except ValueError:
                            print(f"ValueError: invalid literal for int() with base 10: '{value}' in label '{component}'")
            current_assets = [ca + cai for ca, cai in zip(current_assets, current_asset_investments)]
            print("Current Asset Investments value was missing and calculated using components.")
        print("Current Assets value was missing and calculated using components.")
    else:
        current_assets = [int(value.replace(',', '')) for value in current_assets[:2]]  # Use only the first two items

    # Calculate the total balance sheet value for the latest and previous year
    balance_sheet_latest = sum(fixed_assets[-2:-1]) + sum(current_assets[-2:-1])
    balance_sheet_previous = sum(fixed_assets[-1:]) + sum(current_assets[-1:])
    balance_sheet = [balance_sheet_latest, balance_sheet_previous]

    # Convert values to strings with commas for human readability
    turnover = [f"{value:,}" for value in turnover]
    fixed_assets = [f"{value:,}" for value in fixed_assets]
    current_assets = [f"{value:,}" for value in current_assets]
    employees = [f"{value:,}" for value in employees]
    balance_sheet = [f"{value:,}" for value in balance_sheet]

    # Print values in the same column
    print('-'*70)
    print(f"{'Turnover Revenue:':<35} {turnover}")
    print(f"{'Fixed Assets:':<35} {fixed_assets}")
    print(f"{'Current Assets:':<35} {current_assets}")
    print(f"{'Average Number Employees | Period:':<35} {employees}")
    print(f"{'Balance Sheet Total:':<35} {balance_sheet}")
    print('-'*70)

    # Determine the size of the company based on the criteria
    # Check if the company meets at least 2 out of 3 conditions for micro size
    micro_conditions_met = (
        (len(turnover) > 1 and int(turnover[-2].replace(',', '')) <= micro_criteria['turnover']) +
        (int(balance_sheet[-2].replace(',', '')) <= micro_criteria['balance_sheet']) +
        (len(employees) > 1 and int(employees[-2].replace(',', '')) <= micro_criteria['employees'])
    )
    if micro_conditions_met >= 2:
        print(f"Size of Entity: Micro")
        return 'micro'

    # Check if the company meets at least 2 out of 3 conditions for small size
    small_conditions_met = (
        (len(turnover) > 1 and int(turnover[-2].replace(',', '')) <= small_criteria['turnover']) +
        (int(balance_sheet[-2].replace(',', '')) <= small_criteria['balance_sheet']) +
        (len(employees) > 1 and int(employees[-2].replace(',', '')) <= small_criteria['employees'])
    )
    if small_conditions_met >= 2:
        print(f"Size of Entity: Small")
        return 'small'

    # Check if the company meets at least 2 out of 3 conditions for medium size
    medium_conditions_met = (
        (len(turnover) > 1 and int(turnover[-2].replace(',', '')) <= medium_criteria['turnover']) +
        (int(balance_sheet[-2].replace(',', '')) <= medium_criteria['balance_sheet']) +
        (len(employees) > 1 and int(employees[-2].replace(',', '')) <= medium_criteria['employees'])
    )
    if medium_conditions_met >= 2:
        print(f"Size of Entity: Medium")
        return 'medium'

    # If none of the above conditions are met, the company is classified as large
    print(f"Size of Entity: Large")
    return 'large'

# %% [markdown]
# # Load data

# %%
import pandas as pd

path = "csv/UK_SMB_manually_selected_set100.csv"
data = pd.read_csv(path)

data_ixbrl = data[data['ixbrl'] == 1] #select only the rows where ixbrl == 1 (companies that contain xhtml in their filing)

data_ixbrl = data_ixbrl[['company_number', 'company_name', 'ixbrl', 'size']]
data_ixbrl
# Out:
#     company_number                                       company_name  ixbrl  \
# 7            11717  ULVERSTON AUCTION MART PUBLIC LIMITED COMPANY(...      1
# 15         1024277                                  TOTAL SYSTEMS PLC      1
# 19          737075                                   SANDUSKY LIMITED      1
# 20          277871                                ALAN HADLEY LIMITED      1
# 23         2847809                   NORSK EUROPEAN WHOLESALE LIMITED      1
# 27          114709                                 J F ASHTON LIMITED      1
# 30         1349434                                        PSD LIMITED      1
# 31          335313                    COLE & SON (WALLPAPERS) LIMITED      1
# 33          650255                                TORPEDO FACTORY LTD      1
# 34          865285                                     VISTRA LIMITED      1
# 37         1053218                                     TECHEX LIMITED      1
# 48         1130989                           W.T. PARTNERSHIP LIMITED      1
# 49         1185121                   BUTTERWORTH LABORATORIES LIMITED      1
# 58          293103                        W.A. TRUELOVE & SON LIMITED      1
# 61          408782               PRITCHARD PATENT PRODUCT CO. LIMITED      1
# 66          707744                    WILKES VENDING SERVICES LIMITED      1
# 67          762224                        H.G.BLAKE(COSTESSEY)LIMITED      1
# 69          777567                          DOVESTONE ESTATES LIMITED      1
# 74          872451                        P. & F. SAFEPAC CO. LIMITED      1
# 75         1041096                           HAMILTON RENTALS LIMITED      1
# 82         1486255                                       HTEC LIMITED      1
# 83         1500217                                 ATEX MEDIA LIMITED      1
# 84          159161                     PALMERS SCAFFOLDING UK LIMITED      1
# 85          196308        P.C.RICHARDSON & CO.(MIDDLESBROUGH),LIMITED      1
# 86          236372                      COLLINS (CONTRACTORS) LIMITED      1
# 88           43081                             LOAKE BROTHERS LIMITED      1
# 89           66706                        ARIGHI BIANCHI & CO.LIMITED      1
# 96           66471                               G.B. KENT & SONS PLC      1
# 97          156022                                   WALLGATE LIMITED      1
# 98          219220    ARVINMERITOR LIGHT VEHICLE SYSTEMS (UK) LIMITED      1
#
#       size
# 7    small
# 15   small
# 19   small
# 20   small
# 23  medium
# 27  medium
# 30  medium
# 31  medium
# 33   small
# 34   small
# 37  medium
# 48  medium
# 49  medium
# 58  medium
# 61  medium
# 66  medium
# 67  medium
# 69  medium
# 74  medium
# 75  medium
# 82  medium
# 83   small
# 84  medium
# 85  medium
# 86  medium
# 88  medium
# 89  medium
# 96  medium
# 97  medium
# 98   small

# %% [markdown]
# # Evaluate

# %% [markdown]
# ## Notes
#
# The benchmark was againt size classification made by Endole.
# There are cases when the Endole class is outdated, for example for company: G.B. KENT & SONS PLC, currently 'small'.

# %%
sizes = []

print("Starting to process companies...")

for index, row in data_ixbrl.iterrows():
    
    print('#'*100)
    code = str(row['company_number']).zfill(8)
    company_name = row['company_name']
    print(f"\nProcessing company: {company_name} (ID: {code})")

    history = request_filling_history(code)
    print(f"Retrieved filling history for {company_name}")

    filtered_history = [item for item in history['items'] if item.get('type') == 'AA']

    if not filtered_history:
        error_message = f"No 'AA' type items found in history for company ID: {code}"
        print(error_message)
        sizes.append(None)
        continue

    print(f"Found {len(filtered_history)} 'AA' type items for {company_name}")

    for item in filtered_history:
        if check_for_xhtml_pipe(item):
            print(f"XHTML document found for {company_name}")
            
            # Retrieve the URL of the documents
            url = retrieve_documents_url(item)
            print(f"Retrieved document URL for {company_name}")

            # Retrieve the json object containing the documents (pdf + xhtml possibly)
            response = make_get_request(url, headers=None)
            url = response.json()["links"]["document"]
            print(f"Retrieved JSON object for {company_name}")

            # Retrieve the desired document
            headers = {"Accept": "application/xhtml+xml"}
            response = make_get_request(url, headers)
            print(f"Retrieved XHTML document for {company_name}")
            
            # The response should be a binary of the xhtml file
            xhtml_content = response.content.decode("utf-8")

            # Save the xhtml file with company_number, date_str, type_str, and company_name in the file name
            date_str = retrieve_date_from_accounts_item(item)
            type_str = retrieve_type_from_accounts_item(item)
            file_name = f"{code}_{type_str}_{date_str}_{company_name}.xhtml"
            output_directory = "xhtml"
            if not os.path.exists(output_directory):
                os.makedirs(output_directory)
            output_file_path = os.path.join(output_directory, file_name)

            with open(output_file_path, "w", encoding="utf-8") as file:
                file.write(xhtml_content)
            print(f"Saved XHTML file for {company_name}")

            # Classify size
            print(f"Classifying size for {company_name}...")
            # ixbrl_data = retrieve_all_ix_financial_data_minus(output_file_path)
            size = company_size(output_file_path)
            print(f"Company: {company_name}, Size: {size}")
            sizes.append(size)
            break
    else:
        print(f"No XHTML document found for {company_name}")
        sizes.append(None)

print("\nFinished processing all companies.")
# Add the 'size' column to the existing DataFrame
data_ixbrl['size evals'] = sizes
print("Added size data to dataframe.")
# Out:
# Starting to process companies...
# ####################################################################################################
#
# Processing company: ULVERSTON AUCTION MART PUBLIC LIMITED COMPANY(THE) (ID: 00011717)
# Retrieved filling history for ULVERSTON AUCTION MART PUBLIC LIMITED COMPANY(THE)
# Found 8 'AA' type items for ULVERSTON AUCTION MART PUBLIC LIMITED COMPANY(THE)
# XHTML document found for ULVERSTON AUCTION MART PUBLIC LIMITED COMPANY(THE)
# Retrieved document URL for ULVERSTON AUCTION MART PUBLIC LIMITED COMPANY(THE)
# Retrieved JSON object for ULVERSTON AUCTION MART PUBLIC LIMITED COMPANY(THE)
# Retrieved XHTML document for ULVERSTON AUCTION MART PUBLIC LIMITED COMPANY(THE)
# Saved XHTML file for ULVERSTON AUCTION MART PUBLIC LIMITED COMPANY(THE)
# Classifying size for ULVERSTON AUCTION MART PUBLIC LIMITED COMPANY(THE)...
# label: TurnoverRevenue
# item: <ix:nonfraction contextref="c0" decimals="0" format="ixt:numcommadot" name="e:TurnoverRevenue" unitref="u1">673,534</ix:nonfraction>
# temp list: ['673,534']
# item: <ix:nonfraction contextref="c273" decimals="0" format="ixt:numcommadot" name="e:TurnoverRevenue" unitref="u1">614,960</ix:nonfraction>
# temp list: ['673,534', '614,960']
# label: FixedAssets
# item: <ix:nonfraction contextref="c274" decimals="0" format="ixt:numcommadot" name="e:FixedAssets" unitref="u1">219,197</ix:nonfraction>
# temp list: ['219,197']
# item: <ix:nonfraction contextref="c275" decimals="0" format="ixt:numcommadot" name="e:FixedAssets" unitref="u1">216,946</ix:nonfraction>
# temp list: ['219,197', '216,946']
# label: IntangibleAssets
# label: PropertyPlantEquipment
# item: <ix:nonfraction contextref="c274" decimals="0" format="ixt:numcommadot" name="e:PropertyPlantEquipment" unitref="u1">153,547</ix:nonfraction>
# temp list: ['153,547']
# item: <ix:nonfraction contextref="c275" decimals="0" format="ixt:numcommadot" name="e:PropertyPlantEquipment" unitref="u1">151,296</ix:nonfraction>
# temp list: ['153,547', '151,296']
# item: <ix:nonfraction contextref="c415" decimals="0" format="ixt:numcommadot" name="e:PropertyPlantEquipment" unitref="u1">97,546</ix:nonfraction>
# temp list: ['153,547', '151,296', '97,546']
# item: <ix:nonfraction contextref="c454" decimals="0" format="ixt:numcommadot" name="e:PropertyPlantEquipment" unitref="u1">12,808</ix:nonfraction>
# temp list: ['153,547', '151,296', '97,546', '12,808']
# item: <ix:nonfraction contextref="c467" decimals="0" format="ixt:numdash" name="e:PropertyPlantEquipment" unitref="u1">-</ix:nonfraction>
# temp list: ['153,547', '151,296', '97,546', '12,808', '-']
# item: <ix:nonfraction contextref="c493" decimals="0" format="ixt:numcommadot" name="e:PropertyPlantEquipment" unitref="u1">43,193</ix:nonfraction>
# temp list: ['153,547', '151,296', '97,546', '12,808', '-', '43,193']
# item: <ix:nonfraction contextref="c274" decimals="0" format="ixt:numcommadot" name="e:PropertyPlantEquipment" unitref="u1">153,547</ix:nonfraction>
# temp list: ['153,547', '151,296', '97,546', '12,808', '-', '43,193', '153,547']
# item: <ix:nonfraction contextref="c416" decimals="0" format="ixt:numcommadot" name="e:PropertyPlantEquipment" unitref="u1">102,290</ix:nonfraction>
# temp list: ['153,547', '151,296', '97,546', '12,808', '-', '43,193', '153,547', '102,290']
# item: <ix:nonfraction contextref="c455" decimals="0" format="ixt:numcommadot" name="e:PropertyPlantEquipment" unitref="u1">16,027</ix:nonfraction>
# temp list: ['153,547', '151,296', '97,546', '12,808', '-', '43,193', '153,547', '102,290', '16,027']
# item: <ix:nonfraction contextref="c468" decimals="0" format="ixt:numdash" name="e:PropertyPlantEquipment" unitref="u1">-</ix:nonfraction>
# temp list: ['153,547', '151,296', '97,546', '12,808', '-', '43,193', '153,547', '102,290', '16,027', '-']
# item: <ix:nonfraction contextref="c494" decimals="0" format="ixt:numcommadot" name="e:PropertyPlantEquipment" unitref="u1">32,979</ix:nonfraction>
# temp list: ['153,547', '151,296', '97,546', '12,808', '-', '43,193', '153,547', '102,290', '16,027', '-', '32,979']
# item: <ix:nonfraction contextref="c275" decimals="0" format="ixt:numcommadot" name="e:PropertyPlantEquipment" unitref="u1">151,296</ix:nonfraction>
# temp list: ['153,547', '151,296', '97,546', '12,808', '-', '43,193', '153,547', '102,290', '16,027', '-', '32,979', '151,296']
# label: InvestmentsFixedAssets
# item: <ix:nonfraction contextref="c274" decimals="0" format="ixt:numcommadot" name="e:InvestmentsFixedAssets" unitref="u1">65,650</ix:nonfraction>
# temp list: ['65,650']
# item: <ix:nonfraction contextref="c275" decimals="0" format="ixt:numcommadot" name="e:InvestmentsFixedAssets" unitref="u1">65,650</ix:nonfraction>
# temp list: ['65,650', '65,650']
# label: InvestmentsInGroupUndertakings
# label: LoansToGroupUndertakings
# label: InvestmentsInAssociatesJointVenturesParticipatingInterests
# label: LoansToAssociatesJointVenturesParticipatingInterests
# label: OtherInvestmentsOtherThanLoans
# label: OtherLoansClassifiedUnderInvestments
# label: OwnShares
# label: InvestmentProperty
# label: BiologicalAssetsNon-current
# label: CurrentAssets
# item: <ix:nonfraction contextref="c274" decimals="0" format="ixt:numcommadot" name="e:CurrentAssets" unitref="u1">1,658,014</ix:nonfraction>
# temp list: ['1,658,014']
# item: <ix:nonfraction contextref="c275" decimals="0" format="ixt:numcommadot" name="e:CurrentAssets" unitref="u1">1,150,612</ix:nonfraction>
# temp list: ['1,658,014', '1,150,612']
# label: TotalInventories
# item: <ix:nonfraction contextref="c274" decimals="0" format="ixt:numdash" name="e:TotalInventories" unitref="u1">-</ix:nonfraction>
# temp list: ['-']
# item: <ix:nonfraction contextref="c275" decimals="0" format="ixt:numcommadot" name="e:TotalInventories" unitref="u1">1,818</ix:nonfraction>
# temp list: ['-', '1,818']
# label: BiologicalAssetsCurrent
# label: Debtors
# item: <ix:nonfraction contextref="c620" decimals="0" format="ixt:numcommadot" name="e:Debtors" unitref="u1">1,658,014</ix:nonfraction>
# temp list: ['1,658,014']
# item: <ix:nonfraction contextref="c621" decimals="0" format="ixt:numcommadot" name="e:Debtors" unitref="u1">1,087,901</ix:nonfraction>
# temp list: ['1,658,014', '1,087,901']
# item: <ix:nonfraction contextref="c620" decimals="0" format="ixt:numcommadot" name="e:Debtors" unitref="u1">1,658,014</ix:nonfraction>
# temp list: ['1,658,014', '1,087,901', '1,658,014']
# item: <ix:nonfraction contextref="c621" decimals="0" format="ixt:numcommadot" name="e:Debtors" unitref="u1">1,087,901</ix:nonfraction>
# temp list: ['1,658,014', '1,087,901', '1,658,014', '1,087,901']
# label: TradeDebtorsTradeReceivables
# item: <ix:nonfraction contextref="c620" decimals="0" format="ixt:numcommadot" name="e:TradeDebtorsTradeReceivables" unitref="u1">1,644,443</ix:nonfraction>
# temp list: ['1,644,443']
# item: <ix:nonfraction contextref="c621" decimals="0" format="ixt:numcommadot" name="e:TradeDebtorsTradeReceivables" unitref="u1">1,063,279</ix:nonfraction>
# temp list: ['1,644,443', '1,063,279']
# label: AmountsOwedByGroupUndertakings
# label: AmountsOwedByAssociatesJointVenturesParticipatingInterests
# label: OtherDebtorsBalanceSheetSubtotal
# label: CalledUpShareCapitalNotPaidCurrentAsset
# label: PrepaymentsAccruedIncome
# item: <ix:nonfraction contextref="c620" decimals="0" format="ixt:numcommadot" name="e:PrepaymentsAccruedIncome" unitref="u1">12,225</ix:nonfraction>
# temp list: ['12,225']
# item: <ix:nonfraction contextref="c621" decimals="0" format="ixt:numcommadot" name="e:PrepaymentsAccruedIncome" unitref="u1">14,052</ix:nonfraction>
# temp list: ['12,225', '14,052']
# label: DeferredTaxAssetDebtors
# label: CurrentAssetInvestments
# label: InvestmentsInGroupUndertakings
# label: OwnShares
# label: OtherCurrentAssetInvestmentsBalanceSheetSubtotal
# label: CashBankOnHand
# item: <ix:nonfraction contextref="c274" decimals="0" format="ixt:numdash" name="e:CashBankOnHand" unitref="u1">-</ix:nonfraction>
# temp list: ['-']
# item: <ix:nonfraction contextref="c275" decimals="0" format="ixt:numcommadot" name="e:CashBankOnHand" unitref="u1">60,893</ix:nonfraction>
# temp list: ['-', '60,893']
# item: <ix:nonfraction contextref="c274" decimals="0" format="ixt:numdash" name="e:CashBankOnHand" unitref="u1">-</ix:nonfraction>
# temp list: ['-', '60,893', '-']
# item: <ix:nonfraction contextref="c275" decimals="0" format="ixt:numcommadot" name="e:CashBankOnHand" unitref="u1">60,893</ix:nonfraction>
# temp list: ['-', '60,893', '-', '60,893']
# item: <ix:nonfraction contextref="c274" decimals="0" format="ixt:numdash" name="e:CashBankOnHand" unitref="u1">-</ix:nonfraction>
# temp list: ['-', '60,893', '-', '60,893', '-']
# item: <ix:nonfraction contextref="c275" decimals="0" format="ixt:numcommadot" name="e:CashBankOnHand" unitref="u1">60,893</ix:nonfraction>
# temp list: ['-', '60,893', '-', '60,893', '-', '60,893']
# label: AverageNumberEmployeesDuringPeriod
# item: <ix:nonfraction contextref="c273" decimals="0" name="e:AverageNumberEmployeesDuringPeriod" unitref="u8">37</ix:nonfraction>
# temp list: ['37']
# item: <ix:nonfraction contextref="c0" decimals="0" name="e:AverageNumberEmployeesDuringPeriod" unitref="u8">37</ix:nonfraction>
# temp list: ['37', '37']
# item: <ix:nonfraction contextref="c0" decimals="0" name="e:AverageNumberEmployeesDuringPeriod" unitref="u8">37</ix:nonfraction>
# temp list: ['37', '37', '37']
# item: <ix:nonfraction contextref="c273" decimals="0" name="e:AverageNumberEmployeesDuringPeriod" unitref="u8">37</ix:nonfraction>
# temp list: ['37', '37', '37', '37']
# ----------------------------------------------------------------------
# Turnover Revenue:                   ['673,534', '614,960']
# Fixed Assets:                       ['219,197', '216,946']
# Current Assets:                     ['1,658,014', '1,150,612']
# Average Number Employees | Period:  ['37', '37', '37', '37']
# Balance Sheet Total:                ['1,877,211', '1,367,558']
# ----------------------------------------------------------------------
# Size of Entity: Small
# Company: ULVERSTON AUCTION MART PUBLIC LIMITED COMPANY(THE), Size: small
# ####################################################################################################
#
# Processing company: TOTAL SYSTEMS PLC (ID: 01024277)
# Retrieved filling history for TOTAL SYSTEMS PLC
# Found 7 'AA' type items for TOTAL SYSTEMS PLC
# XHTML document found for TOTAL SYSTEMS PLC
# Retrieved document URL for TOTAL SYSTEMS PLC
# Retrieved JSON object for TOTAL SYSTEMS PLC
# Retrieved XHTML document for TOTAL SYSTEMS PLC
# Saved XHTML file for TOTAL SYSTEMS PLC
# Classifying size for TOTAL SYSTEMS PLC...
# label: TurnoverRevenue
# label: FixedAssets
# label: IntangibleAssets
# label: PropertyPlantEquipment
# label: InvestmentsFixedAssets
# label: InvestmentsInGroupUndertakings
# label: LoansToGroupUndertakings
# label: InvestmentsInAssociatesJointVenturesParticipatingInterests
# label: LoansToAssociatesJointVenturesParticipatingInterests
# label: OtherInvestmentsOtherThanLoans
# label: OtherLoansClassifiedUnderInvestments
# label: OwnShares
# label: InvestmentProperty
# label: BiologicalAssetsNon-current
# label: CurrentAssets
# label: TotalInventories
# label: BiologicalAssetsCurrent
# label: Debtors
# label: TradeDebtorsTradeReceivables
# label: AmountsOwedByGroupUndertakings
# label: AmountsOwedByAssociatesJointVenturesParticipatingInterests
# label: OtherDebtorsBalanceSheetSubtotal
# label: CalledUpShareCapitalNotPaidCurrentAsset
# label: PrepaymentsAccruedIncome
# label: DeferredTaxAssetDebtors
# label: CurrentAssetInvestments
# label: InvestmentsInGroupUndertakings
# label: OwnShares
# label: OtherCurrentAssetInvestmentsBalanceSheetSubtotal
# label: CashBankOnHand
# label: AverageNumberEmployeesDuringPeriod
# item: <ix:nonfraction contextref="C" decimals="INF" name="core:AverageNumberEmployeesDuringPeriod" unitref="Pure">32</ix:nonfraction>
# temp list: ['32']
# item: <ix:nonfraction contextref="F" decimals="INF" name="core:AverageNumberEmployeesDuringPeriod" unitref="Pure">31</ix:nonfraction>
# temp list: ['32', '31']
# TurnoverRevenue list is empty.
# attempting to match Turnover
# Found 'Turnover' tag
# Turnover values retrieved from XHTML content: ['2322228', '2299838']
# FixedAssets list is empty.
# CurrentAssets list is empty.
# Investment Fixed Assets value was missing and calculated using components.
# Fixed Assets value was missing and calculated using components.
# Debtors value was missing and calculated using components.
# Current Asset Investments value was missing and calculated using components.
# Current Assets value was missing and calculated using components.
# ----------------------------------------------------------------------
# Turnover Revenue:                   ['2,322,228', '2,299,838']
# Fixed Assets:                       ['0', '0']
# Current Assets:                     ['0', '0']
# Average Number Employees | Period:  ['32', '31']
# Balance Sheet Total:                ['0', '0']
# ----------------------------------------------------------------------
# Size of Entity: Small
# Company: TOTAL SYSTEMS PLC, Size: small
# ####################################################################################################
#
# Processing company: SANDUSKY LIMITED (ID: 00737075)
# Retrieved filling history for SANDUSKY LIMITED
# Found 4 'AA' type items for SANDUSKY LIMITED
# XHTML document found for SANDUSKY LIMITED
# Retrieved document URL for SANDUSKY LIMITED
# Retrieved JSON object for SANDUSKY LIMITED
# Retrieved XHTML document for SANDUSKY LIMITED
# Saved XHTML file for SANDUSKY LIMITED
# Classifying size for SANDUSKY LIMITED...
# label: TurnoverRevenue
# item: <ix:nonfraction contextref="Period_TMinusZero" decimals="0" format="ixt:numcommadot" name="core:TurnoverRevenue" scale="0" unitref="GBP">3,815,607</ix:nonfraction>
# temp list: ['3,815,607']
# item: <ix:nonfraction contextref="Period_TMinusOne" decimals="0" format="ixt:numcommadot" name="core:TurnoverRevenue" scale="0" unitref="GBP">6,023,761</ix:nonfraction>
# temp list: ['3,815,607', '6,023,761']
# item: <ix:nonfraction contextref="UnitedKingdom_Period_TMinusZero" decimals="0" format="ixt:numcommadot" name="core:TurnoverRevenue" scale="0" unitref="GBP">945,888</ix:nonfraction>
# temp list: ['3,815,607', '6,023,761', '945,888']
# item: <ix:nonfraction contextref="UnitedKingdom_Period_TMinusOne" decimals="0" format="ixt:numcommadot" name="core:TurnoverRevenue" scale="0" unitref="GBP">854,403</ix:nonfraction>
# temp list: ['3,815,607', '6,023,761', '945,888', '854,403']
# item: <ix:nonfraction contextref="Period_TMinusZero" decimals="0" format="ixt:numcommadot" name="core:TurnoverRevenue" scale="0" unitref="GBP">3,815,607</ix:nonfraction>
# temp list: ['3,815,607', '6,023,761', '945,888', '854,403', '3,815,607']
# item: <ix:nonfraction contextref="Period_TMinusOne" decimals="0" format="ixt:numcommadot" name="core:TurnoverRevenue" scale="0" unitref="GBP">6,023,761</ix:nonfraction>
# temp list: ['3,815,607', '6,023,761', '945,888', '854,403', '3,815,607', '6,023,761']
# label: FixedAssets
# label: IntangibleAssets
# label: PropertyPlantEquipment
# item: <ix:nonfraction contextref="PeriodEnd_TMinusZero" decimals="0" format="ixt:numcommadot" name="core:PropertyPlantEquipment" scale="0" unitref="GBP">1,272,219</ix:nonfraction>
# temp list: ['1,272,219']
# item: <ix:nonfraction contextref="PeriodEnd_TMinusOne" decimals="0" format="ixt:numcommadot" name="core:PropertyPlantEquipment" scale="0" unitref="GBP">2,904,637</ix:nonfraction>
# temp list: ['1,272,219', '2,904,637']
# item: <ix:nonfraction contextref="LandBuildings_OwnedOrFreeholdAssets_PeriodEnd_TMinusZero" decimals="0" format="ixt:numcommadot" name="core:PropertyPlantEquipment" scale="0" unitref="GBP">1,200,000</ix:nonfraction>
# temp list: ['1,272,219', '2,904,637', '1,200,000']
# item: <ix:nonfraction contextref="LandBuildings_ShortLeaseholdAssets_PeriodEnd_TMinusZero" decimals="0" format="ixt:numcommadot" name="core:PropertyPlantEquipment" scale="0" unitref="GBP">72,219</ix:nonfraction>
# temp list: ['1,272,219', '2,904,637', '1,200,000', '72,219']
# item: <ix:nonfraction contextref="PeriodEnd_TMinusZero" decimals="0" format="ixt:numcommadot" name="core:PropertyPlantEquipment" scale="0" unitref="GBP">1,272,219</ix:nonfraction>
# temp list: ['1,272,219', '2,904,637', '1,200,000', '72,219', '1,272,219']
# item: <ix:nonfraction contextref="LandBuildings_OwnedOrFreeholdAssets_PeriodEnd_TMinusOne" decimals="0" format="ixt:numcommadot" name="core:PropertyPlantEquipment" scale="0" unitref="GBP">825,000</ix:nonfraction>
# temp list: ['1,272,219', '2,904,637', '1,200,000', '72,219', '1,272,219', '825,000']
# item: <ix:nonfraction contextref="LandBuildings_ShortLeaseholdAssets_PeriodEnd_TMinusOne" decimals="0" format="ixt:numcommadot" name="core:PropertyPlantEquipment" scale="0" unitref="GBP">1,207,752</ix:nonfraction>
# temp list: ['1,272,219', '2,904,637', '1,200,000', '72,219', '1,272,219', '825,000', '1,207,752']
# item: <ix:nonfraction contextref="PlantMachinery_PeriodEnd_TMinusOne" decimals="0" format="ixt:numcommadot" name="core:PropertyPlantEquipment" scale="0" unitref="GBP">751,151</ix:nonfraction>
# temp list: ['1,272,219', '2,904,637', '1,200,000', '72,219', '1,272,219', '825,000', '1,207,752', '751,151']
# item: <ix:nonfraction contextref="FurnitureFittings_PeriodEnd_TMinusOne" decimals="0" format="ixt:numcommadot" name="core:PropertyPlantEquipment" scale="0" unitref="GBP">26,233</ix:nonfraction>
# temp list: ['1,272,219', '2,904,637', '1,200,000', '72,219', '1,272,219', '825,000', '1,207,752', '751,151', '26,233']
# item: <ix:nonfraction contextref="PeriodEnd_TMinusOne" decimals="0" format="ixt:numcommadot" name="core:PropertyPlantEquipment" scale="0" unitref="GBP">2,904,637</ix:nonfraction>
# temp list: ['1,272,219', '2,904,637', '1,200,000', '72,219', '1,272,219', '825,000', '1,207,752', '751,151', '26,233', '2,904,637']
# label: InvestmentsFixedAssets
# label: InvestmentsInGroupUndertakings
# label: LoansToGroupUndertakings
# label: InvestmentsInAssociatesJointVenturesParticipatingInterests
# label: LoansToAssociatesJointVenturesParticipatingInterests
# label: OtherInvestmentsOtherThanLoans
# label: OtherLoansClassifiedUnderInvestments
# label: OwnShares
# label: InvestmentProperty
# label: BiologicalAssetsNon-current
# label: CurrentAssets
# item: <ix:nonfraction contextref="PeriodEnd_TMinusZero" decimals="0" format="ixt:numcommadot" name="core:CurrentAssets" scale="0" unitref="GBP">1,187,692</ix:nonfraction>
# temp list: ['1,187,692']
# item: <ix:nonfraction contextref="PeriodEnd_TMinusOne" decimals="0" format="ixt:numcommadot" name="core:CurrentAssets" scale="0" unitref="GBP">3,914,962</ix:nonfraction>
# temp list: ['1,187,692', '3,914,962']
# label: TotalInventories
# item: <ix:nonfraction contextref="PeriodEnd_TMinusZero" decimals="0" format="ixt:numcommadot" name="core:TotalInventories" scale="0" unitref="GBP">35,523</ix:nonfraction>
# temp list: ['35,523']
# item: <ix:nonfraction contextref="PeriodEnd_TMinusOne" decimals="0" format="ixt:numcommadot" name="core:TotalInventories" scale="0" unitref="GBP">2,608,217</ix:nonfraction>
# temp list: ['35,523', '2,608,217']
# item: <ix:nonfraction contextref="PeriodEnd_TMinusZero" decimals="0" format="ixt:numcommadot" name="core:TotalInventories" scale="0" unitref="GBP">35,523</ix:nonfraction>
# temp list: ['35,523', '2,608,217', '35,523']
# item: <ix:nonfraction contextref="PeriodEnd_TMinusOne" decimals="0" format="ixt:numcommadot" name="core:TotalInventories" scale="0" unitref="GBP">2,608,217</ix:nonfraction>
# temp list: ['35,523', '2,608,217', '35,523', '2,608,217']
# label: BiologicalAssetsCurrent
# label: Debtors
# item: <ix:nonfraction contextref="PeriodEnd_TMinusZero" decimals="0" format="ixt:numcommadot" name="core:Debtors" scale="0" unitref="GBP">1,085,439</ix:nonfraction>
# temp list: ['1,085,439']
# item: <ix:nonfraction contextref="PeriodEnd_TMinusOne" decimals="0" format="ixt:numcommadot" name="core:Debtors" scale="0" unitref="GBP">1,263,726</ix:nonfraction>
# temp list: ['1,085,439', '1,263,726']
# item: <ix:nonfraction contextref="PeriodEnd_TMinusZero" decimals="0" format="ixt:numcommadot" name="core:Debtors" scale="0" unitref="GBP">1,085,439</ix:nonfraction>
# temp list: ['1,085,439', '1,263,726', '1,085,439']
# item: <ix:nonfraction contextref="PeriodEnd_TMinusOne" decimals="0" format="ixt:numcommadot" name="core:Debtors" scale="0" unitref="GBP">1,263,726</ix:nonfraction>
# temp list: ['1,085,439', '1,263,726', '1,085,439', '1,263,726']
# label: TradeDebtorsTradeReceivables
# item: <ix:nonfraction contextref="PeriodEnd_TMinusZero" decimals="0" format="ixt:numcommadot" name="core:TradeDebtorsTradeReceivables" scale="0" unitref="GBP">925,180</ix:nonfraction>
# temp list: ['925,180']
# item: <ix:nonfraction contextref="PeriodEnd_TMinusOne" decimals="0" format="ixt:numcommadot" name="core:TradeDebtorsTradeReceivables" scale="0" unitref="GBP">1,075,164</ix:nonfraction>
# temp list: ['925,180', '1,075,164']
# label: AmountsOwedByGroupUndertakings
# item: <ix:nonfraction contextref="PeriodEnd_TMinusZero" decimals="0" format="ixt:numcommadot" name="core:AmountsOwedByGroupUndertakings" scale="0" unitref="GBP">1,724</ix:nonfraction>
# temp list: ['1,724']
# label: AmountsOwedByAssociatesJointVenturesParticipatingInterests
# label: OtherDebtorsBalanceSheetSubtotal
# label: CalledUpShareCapitalNotPaidCurrentAsset
# label: PrepaymentsAccruedIncome
# item: <ix:nonfraction contextref="PeriodEnd_TMinusZero" decimals="0" format="ixt:numcommadot" name="core:PrepaymentsAccruedIncome" scale="0" unitref="GBP">55,503</ix:nonfraction>
# temp list: ['55,503']
# item: <ix:nonfraction contextref="PeriodEnd_TMinusOne" decimals="0" format="ixt:numcommadot" name="core:PrepaymentsAccruedIncome" scale="0" unitref="GBP">95,090</ix:nonfraction>
# temp list: ['55,503', '95,090']
# label: DeferredTaxAssetDebtors
# label: CurrentAssetInvestments
# label: InvestmentsInGroupUndertakings
# label: OwnShares
# label: OtherCurrentAssetInvestmentsBalanceSheetSubtotal
# label: CashBankOnHand
# item: <ix:nonfraction contextref="PeriodEnd_TMinusZero" decimals="0" format="ixt:numcommadot" name="core:CashBankOnHand" scale="0" unitref="GBP">66,730</ix:nonfraction>
# temp list: ['66,730']
# item: <ix:nonfraction contextref="PeriodEnd_TMinusOne" decimals="0" format="ixt:numcommadot" name="core:CashBankOnHand" scale="0" unitref="GBP">43,019</ix:nonfraction>
# temp list: ['66,730', '43,019']
# label: AverageNumberEmployeesDuringPeriod
# item: <ix:nonfraction contextref="Period_TMinusZero" decimals="0" format="ixt:numcommadot" name="core:AverageNumberEmployeesDuringPeriod" scale="0" unitref="Pure">37</ix:nonfraction>
# temp list: ['37']
# FixedAssets list is empty.
# Investment Fixed Assets value was missing and calculated using components.
# Fixed Assets value was missing and calculated using components.
# ----------------------------------------------------------------------
# Turnover Revenue:                   ['3,815,607', '6,023,761', '945,888', '854,403', '3,815,607', '6,023,761']
# Fixed Assets:                       ['1,272,219', '2,904,637']
# Current Assets:                     ['1,187,692', '3,914,962']
# Average Number Employees | Period:  ['37']
# Balance Sheet Total:                ['2,459,911', '6,819,599']
# ----------------------------------------------------------------------
# Size of Entity: Small
# Company: SANDUSKY LIMITED, Size: small
# ####################################################################################################
#
# Processing company: ALAN HADLEY LIMITED (ID: 00277871)
# Retrieved filling history for ALAN HADLEY LIMITED
# Found 9 'AA' type items for ALAN HADLEY LIMITED
# XHTML document found for ALAN HADLEY LIMITED
# Retrieved document URL for ALAN HADLEY LIMITED
# Retrieved JSON object for ALAN HADLEY LIMITED
# Retrieved XHTML document for ALAN HADLEY LIMITED
# Saved XHTML file for ALAN HADLEY LIMITED
# Classifying size for ALAN HADLEY LIMITED...
# label: TurnoverRevenue
# item: <ix:nonfraction contextref="c1" decimals="0" format="ixt:numcommadot" name="d:TurnoverRevenue" unitref="u0">6,236,521</ix:nonfraction>
# temp list: ['6,236,521']
# item: <ix:nonfraction contextref="c2" decimals="0" format="ixt:numcommadot" name="d:TurnoverRevenue" unitref="u0">5,656,369</ix:nonfraction>
# temp list: ['6,236,521', '5,656,369']
# label: FixedAssets
# label: IntangibleAssets
# label: PropertyPlantEquipment
# item: <ix:nonfraction contextref="c3" decimals="0" format="ixt:numcommadot" name="d:PropertyPlantEquipment" unitref="u0">1,628,886</ix:nonfraction>
# temp list: ['1,628,886']
# item: <ix:nonfraction contextref="c4" decimals="0" format="ixt:numcommadot" name="d:PropertyPlantEquipment" unitref="u0">1,980,225</ix:nonfraction>
# temp list: ['1,628,886', '1,980,225']
# item: <ix:nonfraction contextref="c155" decimals="0" name="d:PropertyPlantEquipment" unitref="u0">1</ix:nonfraction>
# temp list: ['1,628,886', '1,980,225', '1']
# item: <ix:nonfraction contextref="c181" decimals="0" format="ixt:numcommadot" name="d:PropertyPlantEquipment" unitref="u0">932,539</ix:nonfraction>
# temp list: ['1,628,886', '1,980,225', '1', '932,539']
# item: <ix:nonfraction contextref="c194" decimals="0" format="ixt:numcommadot" name="d:PropertyPlantEquipment" unitref="u0">696,346</ix:nonfraction>
# temp list: ['1,628,886', '1,980,225', '1', '932,539', '696,346']
# item: <ix:nonfraction contextref="c246" decimals="0" format="ixt:numdash" name="d:PropertyPlantEquipment" unitref="u0">-</ix:nonfraction>
# temp list: ['1,628,886', '1,980,225', '1', '932,539', '696,346', '-']
# item: <ix:nonfraction contextref="c3" decimals="0" format="ixt:numcommadot" name="d:PropertyPlantEquipment" unitref="u0">1,628,886</ix:nonfraction>
# temp list: ['1,628,886', '1,980,225', '1', '932,539', '696,346', '-', '1,628,886']
# item: <ix:nonfraction contextref="c156" decimals="0" name="d:PropertyPlantEquipment" unitref="u0">1</ix:nonfraction>
# temp list: ['1,628,886', '1,980,225', '1', '932,539', '696,346', '-', '1,628,886', '1']
# item: <ix:nonfraction contextref="c182" decimals="0" format="ixt:numcommadot" name="d:PropertyPlantEquipment" unitref="u0">1,227,882</ix:nonfraction>
# temp list: ['1,628,886', '1,980,225', '1', '932,539', '696,346', '-', '1,628,886', '1', '1,227,882']
# item: <ix:nonfraction contextref="c195" decimals="0" format="ixt:numcommadot" name="d:PropertyPlantEquipment" unitref="u0">752,342</ix:nonfraction>
# temp list: ['1,628,886', '1,980,225', '1', '932,539', '696,346', '-', '1,628,886', '1', '1,227,882', '752,342']
# item: <ix:nonfraction contextref="c247" decimals="0" format="ixt:numdash" name="d:PropertyPlantEquipment" unitref="u0">-</ix:nonfraction>
# temp list: ['1,628,886', '1,980,225', '1', '932,539', '696,346', '-', '1,628,886', '1', '1,227,882', '752,342', '-']
# item: <ix:nonfraction contextref="c4" decimals="0" format="ixt:numcommadot" name="d:PropertyPlantEquipment" unitref="u0">1,980,225</ix:nonfraction>
# temp list: ['1,628,886', '1,980,225', '1', '932,539', '696,346', '-', '1,628,886', '1', '1,227,882', '752,342', '-', '1,980,225']
# label: InvestmentsFixedAssets
# label: InvestmentsInGroupUndertakings
# label: LoansToGroupUndertakings
# label: InvestmentsInAssociatesJointVenturesParticipatingInterests
# label: LoansToAssociatesJointVenturesParticipatingInterests
# label: OtherInvestmentsOtherThanLoans
# label: OtherLoansClassifiedUnderInvestments
# label: OwnShares
# label: InvestmentProperty
# label: BiologicalAssetsNon-current
# label: CurrentAssets
# item: <ix:nonfraction contextref="c3" decimals="0" format="ixt:numcommadot" name="d:CurrentAssets" unitref="u0">887,116</ix:nonfraction>
# temp list: ['887,116']
# item: <ix:nonfraction contextref="c4" decimals="0" format="ixt:numcommadot" name="d:CurrentAssets" unitref="u0">773,275</ix:nonfraction>
# temp list: ['887,116', '773,275']
# label: TotalInventories
# label: BiologicalAssetsCurrent
# label: Debtors
# item: <ix:nonfraction contextref="c347" decimals="0" format="ixt:numcommadot" name="d:Debtors" unitref="u0">887,016</ix:nonfraction>
# temp list: ['887,016']
# item: <ix:nonfraction contextref="c348" decimals="0" format="ixt:numcommadot" name="d:Debtors" unitref="u0">773,175</ix:nonfraction>
# temp list: ['887,016', '773,175']
# item: <ix:nonfraction contextref="c347" decimals="0" format="ixt:numcommadot" name="d:Debtors" unitref="u0">887,016</ix:nonfraction>
# temp list: ['887,016', '773,175', '887,016']
# item: <ix:nonfraction contextref="c348" decimals="0" format="ixt:numcommadot" name="d:Debtors" unitref="u0">773,175</ix:nonfraction>
# temp list: ['887,016', '773,175', '887,016', '773,175']
# label: TradeDebtorsTradeReceivables
# item: <ix:nonfraction contextref="c347" decimals="0" format="ixt:numcommadot" name="d:TradeDebtorsTradeReceivables" unitref="u0">800,834</ix:nonfraction>
# temp list: ['800,834']
# item: <ix:nonfraction contextref="c348" decimals="0" format="ixt:numcommadot" name="d:TradeDebtorsTradeReceivables" unitref="u0">616,810</ix:nonfraction>
# temp list: ['800,834', '616,810']
# label: AmountsOwedByGroupUndertakings
# label: AmountsOwedByAssociatesJointVenturesParticipatingInterests
# label: OtherDebtorsBalanceSheetSubtotal
# label: CalledUpShareCapitalNotPaidCurrentAsset
# label: PrepaymentsAccruedIncome
# item: <ix:nonfraction contextref="c347" decimals="0" format="ixt:numcommadot" name="d:PrepaymentsAccruedIncome" unitref="u0">82,195</ix:nonfraction>
# temp list: ['82,195']
# item: <ix:nonfraction contextref="c348" decimals="0" format="ixt:numcommadot" name="d:PrepaymentsAccruedIncome" unitref="u0">147,052</ix:nonfraction>
# temp list: ['82,195', '147,052']
# label: DeferredTaxAssetDebtors
# label: CurrentAssetInvestments
# label: InvestmentsInGroupUndertakings
# label: OwnShares
# label: OtherCurrentAssetInvestmentsBalanceSheetSubtotal
# label: CashBankOnHand
# item: <ix:nonfraction contextref="c3" decimals="0" name="d:CashBankOnHand" unitref="u0">100</ix:nonfraction>
# temp list: ['100']
# item: <ix:nonfraction contextref="c4" decimals="0" name="d:CashBankOnHand" unitref="u0">100</ix:nonfraction>
# temp list: ['100', '100']
# item: <ix:nonfraction contextref="c3" decimals="0" name="d:CashBankOnHand" unitref="u0">100</ix:nonfraction>
# temp list: ['100', '100', '100']
# item: <ix:nonfraction contextref="c4" decimals="0" name="d:CashBankOnHand" unitref="u0">100</ix:nonfraction>
# temp list: ['100', '100', '100', '100']
# label: AverageNumberEmployeesDuringPeriod
# item: <ix:nonfraction contextref="c1" decimals="0" name="d:AverageNumberEmployeesDuringPeriod" unitref="u8">38</ix:nonfraction>
# temp list: ['38']
# item: <ix:nonfraction contextref="c2" decimals="0" name="d:AverageNumberEmployeesDuringPeriod" unitref="u8">39</ix:nonfraction>
# temp list: ['38', '39']
# item: <ix:nonfraction contextref="c1" decimals="0" name="d:AverageNumberEmployeesDuringPeriod" unitref="u8">38</ix:nonfraction>
# temp list: ['38', '39', '38']
# item: <ix:nonfraction contextref="c2" decimals="0" name="d:AverageNumberEmployeesDuringPeriod" unitref="u8">39</ix:nonfraction>
# temp list: ['38', '39', '38', '39']
# FixedAssets list is empty.
# Investment Fixed Assets value was missing and calculated using components.
# Fixed Assets value was missing and calculated using components.
# ----------------------------------------------------------------------
# Turnover Revenue:                   ['6,236,521', '5,656,369']
# Fixed Assets:                       ['1,628,886', '1,980,225']
# Current Assets:                     ['887,116', '773,275']
# Average Number Employees | Period:  ['38', '39', '38', '39']
# Balance Sheet Total:                ['2,516,002', '2,753,500']
# ----------------------------------------------------------------------
# Size of Entity: Small
# Company: ALAN HADLEY LIMITED, Size: small
# ####################################################################################################
#
# Processing company: NORSK EUROPEAN WHOLESALE LIMITED (ID: 02847809)
# Retrieved filling history for NORSK EUROPEAN WHOLESALE LIMITED
# Found 9 'AA' type items for NORSK EUROPEAN WHOLESALE LIMITED
# XHTML document found for NORSK EUROPEAN WHOLESALE LIMITED
# Retrieved document URL for NORSK EUROPEAN WHOLESALE LIMITED
# Retrieved JSON object for NORSK EUROPEAN WHOLESALE LIMITED
# Retrieved XHTML document for NORSK EUROPEAN WHOLESALE LIMITED
# Saved XHTML file for NORSK EUROPEAN WHOLESALE LIMITED
# Classifying size for NORSK EUROPEAN WHOLESALE LIMITED...
# label: TurnoverRevenue
# item: <ix:nonfraction contextref="C" decimals="0" format="ixt:numcommadot" name="core:TurnoverRevenue" scale="0" unitref="GBP">32,972,026</ix:nonfraction>
# temp list: ['32,972,026']
# item: <ix:nonfraction contextref="F" decimals="0" format="ixt:numcommadot" name="core:TurnoverRevenue" scale="0" unitref="GBP">32,685,507</ix:nonfraction>
# temp list: ['32,972,026', '32,685,507']
# label: FixedAssets
# item: <ix:nonfraction contextref="B" decimals="0" format="ixt:numcommadot" name="core:FixedAssets" scale="0" unitref="GBP">2,461,011</ix:nonfraction>
# temp list: ['2,461,011']
# item: <ix:nonfraction contextref="E" decimals="0" format="ixt:numcommadot" name="core:FixedAssets" scale="0" unitref="GBP">1,902,500</ix:nonfraction>
# temp list: ['2,461,011', '1,902,500']
# label: IntangibleAssets
# item: <ix:nonfraction contextref="B_EZ_FA" decimals="0" format="ixt:numcommadot" name="core:IntangibleAssets" scale="0" unitref="GBP">274,268</ix:nonfraction>
# temp list: ['274,268']
# item: <ix:nonfraction contextref="E_EZ_FA" decimals="0" format="ixt:numcommadot" name="core:IntangibleAssets" scale="0" unitref="GBP">327,374</ix:nonfraction>
# temp list: ['274,268', '327,374']
# item: <ix:nonfraction contextref="B_EZ_GV" decimals="0" format="ixt:numcommadot" name="core:IntangibleAssets" scale="0" unitref="GBP">274,268</ix:nonfraction>
# temp list: ['274,268', '327,374', '274,268']
# item: <ix:nonfraction contextref="E_EZ_GV" decimals="0" format="ixt:numcommadot" name="core:IntangibleAssets" scale="0" unitref="GBP">327,374</ix:nonfraction>
# temp list: ['274,268', '327,374', '274,268', '327,374']
# label: PropertyPlantEquipment
# item: <ix:nonfraction contextref="B" decimals="0" format="ixt:numcommadot" name="core:PropertyPlantEquipment" scale="0" unitref="GBP">2,186,743</ix:nonfraction>
# temp list: ['2,186,743']
# item: <ix:nonfraction contextref="E" decimals="0" format="ixt:numcommadot" name="core:PropertyPlantEquipment" scale="0" unitref="GBP">1,575,126</ix:nonfraction>
# temp list: ['2,186,743', '1,575,126']
# item: <ix:nonfraction contextref="B_FE_GW" decimals="0" format="ixt:numcommadot" name="core:PropertyPlantEquipment" scale="0" unitref="GBP">17,237</ix:nonfraction>
# temp list: ['2,186,743', '1,575,126', '17,237']
# item: <ix:nonfraction contextref="B_FE_GX" decimals="0" format="ixt:numcommadot" name="core:PropertyPlantEquipment" scale="0" unitref="GBP">568,399</ix:nonfraction>
# temp list: ['2,186,743', '1,575,126', '17,237', '568,399']
# item: <ix:nonfraction contextref="B_FE_GY" decimals="0" format="ixt:numcommadot" name="core:PropertyPlantEquipment" scale="0" unitref="GBP">999,766</ix:nonfraction>
# temp list: ['2,186,743', '1,575,126', '17,237', '568,399', '999,766']
# item: <ix:nonfraction contextref="B_FE_GZ" decimals="0" format="ixt:numcommadot" name="core:PropertyPlantEquipment" scale="0" unitref="GBP">601,341</ix:nonfraction>
# temp list: ['2,186,743', '1,575,126', '17,237', '568,399', '999,766', '601,341']
# item: <ix:nonfraction contextref="B" decimals="0" format="ixt:numcommadot" name="core:PropertyPlantEquipment" scale="0" unitref="GBP">2,186,743</ix:nonfraction>
# temp list: ['2,186,743', '1,575,126', '17,237', '568,399', '999,766', '601,341', '2,186,743']
# item: <ix:nonfraction contextref="E_FE_GW" decimals="0" format="ixt:numcommadot" name="core:PropertyPlantEquipment" scale="0" unitref="GBP">23,702</ix:nonfraction>
# temp list: ['2,186,743', '1,575,126', '17,237', '568,399', '999,766', '601,341', '2,186,743', '23,702']
# item: <ix:nonfraction contextref="E_FE_GX" decimals="0" format="ixt:numcommadot" name="core:PropertyPlantEquipment" scale="0" unitref="GBP">356,682</ix:nonfraction>
# temp list: ['2,186,743', '1,575,126', '17,237', '568,399', '999,766', '601,341', '2,186,743', '23,702', '356,682']
# item: <ix:nonfraction contextref="E_FE_GY" decimals="0" format="ixt:numcommadot" name="core:PropertyPlantEquipment" scale="0" unitref="GBP">989,490</ix:nonfraction>
# temp list: ['2,186,743', '1,575,126', '17,237', '568,399', '999,766', '601,341', '2,186,743', '23,702', '356,682', '989,490']
# item: <ix:nonfraction contextref="E_FE_GZ" decimals="0" format="ixt:numcommadot" name="core:PropertyPlantEquipment" scale="0" unitref="GBP">205,252</ix:nonfraction>
# temp list: ['2,186,743', '1,575,126', '17,237', '568,399', '999,766', '601,341', '2,186,743', '23,702', '356,682', '989,490', '205,252']
# item: <ix:nonfraction contextref="E" decimals="0" format="ixt:numcommadot" name="core:PropertyPlantEquipment" scale="0" unitref="GBP">1,575,126</ix:nonfraction>
# temp list: ['2,186,743', '1,575,126', '17,237', '568,399', '999,766', '601,341', '2,186,743', '23,702', '356,682', '989,490', '205,252', '1,575,126']
# label: InvestmentsFixedAssets
# label: InvestmentsInGroupUndertakings
# label: LoansToGroupUndertakings
# label: InvestmentsInAssociatesJointVenturesParticipatingInterests
# label: LoansToAssociatesJointVenturesParticipatingInterests
# label: OtherInvestmentsOtherThanLoans
# label: OtherLoansClassifiedUnderInvestments
# label: OwnShares
# label: InvestmentProperty
# label: BiologicalAssetsNon-current
# label: CurrentAssets
# item: <ix:nonfraction contextref="B" decimals="0" format="ixt:numcommadot" name="core:CurrentAssets" scale="0" unitref="GBP">5,679,009</ix:nonfraction>
# temp list: ['5,679,009']
# item: <ix:nonfraction contextref="E" decimals="0" format="ixt:numcommadot" name="core:CurrentAssets" scale="0" unitref="GBP">5,869,964</ix:nonfraction>
# temp list: ['5,679,009', '5,869,964']
# label: TotalInventories
# label: BiologicalAssetsCurrent
# label: Debtors
# item: <ix:nonfraction contextref="B" decimals="0" format="ixt:numcommadot" name="core:Debtors" scale="0" unitref="GBP">5,021,672</ix:nonfraction>
# temp list: ['5,021,672']
# item: <ix:nonfraction contextref="E" decimals="0" format="ixt:numcommadot" name="core:Debtors" scale="0" unitref="GBP">5,780,263</ix:nonfraction>
# temp list: ['5,021,672', '5,780,263']
# item: <ix:nonfraction contextref="B_FG_GF_FK_GG" decimals="0" format="ixt:numcommadot" name="core:Debtors" scale="0" unitref="GBP">5,021,672</ix:nonfraction>
# temp list: ['5,021,672', '5,780,263', '5,021,672']
# item: <ix:nonfraction contextref="E_FG_GF_FK_GG" decimals="0" format="ixt:numcommadot" name="core:Debtors" scale="0" unitref="GBP">5,780,263</ix:nonfraction>
# temp list: ['5,021,672', '5,780,263', '5,021,672', '5,780,263']
# label: TradeDebtorsTradeReceivables
# item: <ix:nonfraction contextref="B_FG_GF" decimals="0" format="ixt:numcommadot" name="core:TradeDebtorsTradeReceivables" scale="0" unitref="GBP">4,245,862</ix:nonfraction>
# temp list: ['4,245,862']
# item: <ix:nonfraction contextref="E_FG_GF" decimals="0" format="ixt:numcommadot" name="core:TradeDebtorsTradeReceivables" scale="0" unitref="GBP">5,174,194</ix:nonfraction>
# temp list: ['4,245,862', '5,174,194']
# label: AmountsOwedByGroupUndertakings
# label: AmountsOwedByAssociatesJointVenturesParticipatingInterests
# label: OtherDebtorsBalanceSheetSubtotal
# label: CalledUpShareCapitalNotPaidCurrentAsset
# label: PrepaymentsAccruedIncome
# item: <ix:nonfraction contextref="B_FG_GF" decimals="0" format="ixt:numcommadot" name="core:PrepaymentsAccruedIncome" scale="0" unitref="GBP">672,523</ix:nonfraction>
# temp list: ['672,523']
# item: <ix:nonfraction contextref="E_FG_GF" decimals="0" format="ixt:numcommadot" name="core:PrepaymentsAccruedIncome" scale="0" unitref="GBP">452,173</ix:nonfraction>
# temp list: ['672,523', '452,173']
# label: DeferredTaxAssetDebtors
# label: CurrentAssetInvestments
# label: InvestmentsInGroupUndertakings
# label: OwnShares
# label: OtherCurrentAssetInvestmentsBalanceSheetSubtotal
# label: CashBankOnHand
# item: <ix:nonfraction contextref="B" decimals="0" format="ixt:numcommadot" name="core:CashBankOnHand" scale="0" unitref="GBP">657,337</ix:nonfraction>
# temp list: ['657,337']
# item: <ix:nonfraction contextref="E" decimals="0" format="ixt:numcommadot" name="core:CashBankOnHand" scale="0" unitref="GBP">89,701</ix:nonfraction>
# temp list: ['657,337', '89,701']
# item: <ix:nonfraction contextref="B" decimals="0" format="ixt:numcommadot" name="core:CashBankOnHand" scale="0" unitref="GBP">657,337</ix:nonfraction>
# temp list: ['657,337', '89,701', '657,337']
# item: <ix:nonfraction contextref="E" decimals="0" format="ixt:numcommadot" name="core:CashBankOnHand" scale="0" unitref="GBP">89,701</ix:nonfraction>
# temp list: ['657,337', '89,701', '657,337', '89,701']
# label: AverageNumberEmployeesDuringPeriod
# item: <ix:nonfraction contextref="C" decimals="INF" name="core:AverageNumberEmployeesDuringPeriod" unitref="Pure">210</ix:nonfraction>
# temp list: ['210']
# item: <ix:nonfraction contextref="F" decimals="INF" name="core:AverageNumberEmployeesDuringPeriod" unitref="Pure">218</ix:nonfraction>
# temp list: ['210', '218']
# ----------------------------------------------------------------------
# Turnover Revenue:                   ['32,972,026', '32,685,507']
# Fixed Assets:                       ['2,461,011', '1,902,500']
# Current Assets:                     ['5,679,009', '5,869,964']
# Average Number Employees | Period:  ['210', '218']
# Balance Sheet Total:                ['8,140,020', '7,772,464']
# ----------------------------------------------------------------------
# Size of Entity: Medium
# Company: NORSK EUROPEAN WHOLESALE LIMITED, Size: medium
# ####################################################################################################
#
# Processing company: J F ASHTON LIMITED (ID: 00114709)
# Retrieved filling history for J F ASHTON LIMITED
# Found 2 'AA' type items for J F ASHTON LIMITED
# XHTML document found for J F ASHTON LIMITED
# Retrieved document URL for J F ASHTON LIMITED
# Retrieved JSON object for J F ASHTON LIMITED
# Retrieved XHTML document for J F ASHTON LIMITED
# Saved XHTML file for J F ASHTON LIMITED
# Classifying size for J F ASHTON LIMITED...
# label: TurnoverRevenue
# label: FixedAssets
# label: IntangibleAssets
# label: PropertyPlantEquipment
# label: InvestmentsFixedAssets
# label: InvestmentsInGroupUndertakings
# label: LoansToGroupUndertakings
# label: InvestmentsInAssociatesJointVenturesParticipatingInterests
# label: LoansToAssociatesJointVenturesParticipatingInterests
# label: OtherInvestmentsOtherThanLoans
# label: OtherLoansClassifiedUnderInvestments
# label: OwnShares
# label: InvestmentProperty
# label: BiologicalAssetsNon-current
# label: CurrentAssets
# item: <ix:nonfraction contextref="B" decimals="0" format="ixt:numcommadot" name="core:CurrentAssets" scale="0" unitref="GBP">12,077,019</ix:nonfraction>
# temp list: ['12,077,019']
# item: <ix:nonfraction contextref="E" decimals="0" format="ixt:numcommadot" name="core:CurrentAssets" scale="0" unitref="GBP">12,126,377</ix:nonfraction>
# temp list: ['12,077,019', '12,126,377']
# label: TotalInventories
# label: BiologicalAssetsCurrent
# label: Debtors
# item: <ix:nonfraction contextref="B" decimals="0" format="ixt:numcommadot" name="core:Debtors" scale="0" unitref="GBP">5,991,921</ix:nonfraction>
# temp list: ['5,991,921']
# item: <ix:nonfraction contextref="E" decimals="0" format="ixt:numcommadot" name="core:Debtors" scale="0" unitref="GBP">6,473,282</ix:nonfraction>
# temp list: ['5,991,921', '6,473,282']
# item: <ix:nonfraction contextref="B_UM_UX_UQ_UY" decimals="0" format="ixt:numcommadot" name="core:Debtors" scale="0" unitref="GBP">5,991,921</ix:nonfraction>
# temp list: ['5,991,921', '6,473,282', '5,991,921']
# item: <ix:nonfraction contextref="E_UM_UX_UQ_UY" decimals="0" format="ixt:numcommadot" name="core:Debtors" scale="0" unitref="GBP">6,473,282</ix:nonfraction>
# temp list: ['5,991,921', '6,473,282', '5,991,921', '6,473,282']
# label: TradeDebtorsTradeReceivables
# item: <ix:nonfraction contextref="B_UM_UX" decimals="0" format="ixt:numcommadot" name="core:TradeDebtorsTradeReceivables" scale="0" unitref="GBP">2,980</ix:nonfraction>
# temp list: ['2,980']
# item: <ix:nonfraction contextref="E_UM_UX" decimals="0" format="ixt:numcommadot" name="core:TradeDebtorsTradeReceivables" scale="0" unitref="GBP">0</ix:nonfraction>
# temp list: ['2,980', '0']
# label: AmountsOwedByGroupUndertakings
# label: AmountsOwedByAssociatesJointVenturesParticipatingInterests
# label: OtherDebtorsBalanceSheetSubtotal
# label: CalledUpShareCapitalNotPaidCurrentAsset
# label: PrepaymentsAccruedIncome
# label: DeferredTaxAssetDebtors
# label: CurrentAssetInvestments
# label: InvestmentsInGroupUndertakings
# label: OwnShares
# label: OtherCurrentAssetInvestmentsBalanceSheetSubtotal
# label: CashBankOnHand
# label: AverageNumberEmployeesDuringPeriod
# item: <ix:nonfraction contextref="C" decimals="INF" format="ixt:numcommadot" name="core:AverageNumberEmployeesDuringPeriod" unitref="Pure">0</ix:nonfraction>
# temp list: ['0']
# TurnoverRevenue list is empty.
# attempting to match Turnover
# Found 'Turnover' tag
# Turnover values retrieved from XHTML content: ['62909', '54475']
# FixedAssets list is empty.
# Investment Fixed Assets value was missing and calculated using components.
# Fixed Assets value was missing and calculated using components.
# ----------------------------------------------------------------------
# Turnover Revenue:                   ['62,909', '54,475']
# Fixed Assets:                       ['0', '0']
# Current Assets:                     ['12,077,019', '12,126,377']
# Average Number Employees | Period:  ['0']
# Balance Sheet Total:                ['12,077,019', '12,126,377']
# ----------------------------------------------------------------------
# Size of Entity: Medium
# Company: J F ASHTON LIMITED, Size: medium
# ####################################################################################################
#
# Processing company: PSD LIMITED (ID: 01349434)
# Retrieved filling history for PSD LIMITED
# Found 10 'AA' type items for PSD LIMITED
# XHTML document found for PSD LIMITED
# Retrieved document URL for PSD LIMITED
# Retrieved JSON object for PSD LIMITED
# Retrieved XHTML document for PSD LIMITED
# Saved XHTML file for PSD LIMITED
# Classifying size for PSD LIMITED...
# label: TurnoverRevenue
# item: <ix:nonfraction contextref="C" decimals="0" format="ixt:numcommadot" name="core:TurnoverRevenue" scale="0" unitref="GBP">11,366,806</ix:nonfraction>
# temp list: ['11,366,806']
# item: <ix:nonfraction contextref="F" decimals="0" format="ixt:numcommadot" name="core:TurnoverRevenue" scale="0" unitref="GBP">9,558,158</ix:nonfraction>
# temp list: ['11,366,806', '9,558,158']
# label: FixedAssets
# item: <ix:nonfraction contextref="B" decimals="0" format="ixt:numcommadot" name="core:FixedAssets" scale="0" unitref="GBP">138,284</ix:nonfraction>
# temp list: ['138,284']
# item: <ix:nonfraction contextref="E" decimals="0" format="ixt:numcommadot" name="core:FixedAssets" scale="0" unitref="GBP">254,821</ix:nonfraction>
# temp list: ['138,284', '254,821']
# label: IntangibleAssets
# item: <ix:nonfraction contextref="B_OA_OB" decimals="0" format="ixt:numcommadot" name="core:IntangibleAssets" scale="0" unitref="GBP">22,341</ix:nonfraction>
# temp list: ['22,341']
# item: <ix:nonfraction contextref="E_OA_OB" decimals="0" format="ixt:numcommadot" name="core:IntangibleAssets" scale="0" unitref="GBP">25,241</ix:nonfraction>
# temp list: ['22,341', '25,241']
# item: <ix:nonfraction contextref="B_OA_PO" decimals="0" format="ixt:numcommadot" name="core:IntangibleAssets" scale="0" unitref="GBP">22,341</ix:nonfraction>
# temp list: ['22,341', '25,241', '22,341']
# item: <ix:nonfraction contextref="E_OA_PO" decimals="0" format="ixt:numcommadot" name="core:IntangibleAssets" scale="0" unitref="GBP">25,241</ix:nonfraction>
# temp list: ['22,341', '25,241', '22,341', '25,241']
# label: PropertyPlantEquipment
# item: <ix:nonfraction contextref="B" decimals="0" format="ixt:numcommadot" name="core:PropertyPlantEquipment" scale="0" unitref="GBP">115,941</ix:nonfraction>
# temp list: ['115,941']
# item: <ix:nonfraction contextref="E" decimals="0" format="ixt:numcommadot" name="core:PropertyPlantEquipment" scale="0" unitref="GBP">229,578</ix:nonfraction>
# temp list: ['115,941', '229,578']
# item: <ix:nonfraction contextref="B_OF_PP" decimals="0" format="ixt:numcommadot" name="core:PropertyPlantEquipment" scale="0" unitref="GBP">114,587</ix:nonfraction>
# temp list: ['115,941', '229,578', '114,587']
# item: <ix:nonfraction contextref="B_OF_PQ" decimals="0" format="ixt:numcommadot" name="core:PropertyPlantEquipment" scale="0" unitref="GBP">0</ix:nonfraction>
# temp list: ['115,941', '229,578', '114,587', '0']
# item: <ix:nonfraction contextref="B_OF_PR" decimals="0" format="ixt:numcommadot" name="core:PropertyPlantEquipment" scale="0" unitref="GBP">1,354</ix:nonfraction>
# ...
#
# Processing company: WALLGATE LIMITED (ID: 00156022)
# Retrieved filling history for WALLGATE LIMITED
# Found 6 'AA' type items for WALLGATE LIMITED
# XHTML document found for WALLGATE LIMITED
# Retrieved document URL for WALLGATE LIMITED
# Retrieved JSON object for WALLGATE LIMITED
# Retrieved XHTML document for WALLGATE LIMITED
# Saved XHTML file for WALLGATE LIMITED
# Classifying size for WALLGATE LIMITED...
# label: TurnoverRevenue
# item: <ix:nonfraction contextref="BasicHypercube_FY_30_09_2023_Set4" decimals="0" format="ixt2:numdotdecimal" name="ns5:TurnoverRevenue" scale="0" unitref="GBP">11,351,248</ix:nonfraction>
# temp list: ['11,351,248']
# item: <ix:nonfraction contextref="Income-MainHypercube_FY_30_09_2022_Set1" decimals="0" format="ixt2:numdotdecimal" name="ns5:TurnoverRevenue" scale="0" unitref="GBP">10,813,162</ix:nonfraction>
# temp list: ['11,351,248', '10,813,162']
# label: FixedAssets
# item: <ix:nonfraction contextref="BasicHypercube_cfwd_30_09_2023_Set1" decimals="0" format="ixt2:numdotdecimal" name="ns5:FixedAssets" scale="0" unitref="GBP">1,073,440</ix:nonfraction>
# temp list: ['1,073,440']
# item: <ix:nonfraction contextref="Intangibles-SegmentsHypercube_cfwd_30_09_2022_Set1" decimals="0" format="ixt2:numdotdecimal" name="ns5:FixedAssets" scale="0" unitref="GBP">989,295</ix:nonfraction>
# temp list: ['1,073,440', '989,295']
# label: IntangibleAssets
# item: <ix:nonfraction contextref="BasicHypercube_cfwd_30_09_2023_Set1" decimals="0" format="ixt2:numdotdecimal" name="ns5:IntangibleAssets" scale="0" unitref="GBP">181,671</ix:nonfraction>
# temp list: ['181,671']
# item: <ix:nonfraction contextref="Intangibles-SegmentsHypercube_cfwd_30_09_2022_Set1" decimals="0" format="ixt2:numdotdecimal" name="ns5:IntangibleAssets" scale="0" unitref="GBP">118,757</ix:nonfraction>
# temp list: ['181,671', '118,757']
# item: <ix:nonfraction contextref="Intangibles-SegmentsHypercube_cfwd_30_09_2023_Set5" decimals="0" format="ixt2:numdotdecimal" name="ns5:IntangibleAssets" scale="0" unitref="GBP">110,263</ix:nonfraction>
# temp list: ['181,671', '118,757', '110,263']
# item: <ix:nonfraction contextref="Intangibles-SegmentsHypercube_cfwd_30_09_2023_Set6" decimals="0" format="ixt2:numdotdecimal" name="ns5:IntangibleAssets" scale="0" unitref="GBP">71,408</ix:nonfraction>
# temp list: ['181,671', '118,757', '110,263', '71,408']
# item: <ix:nonfraction contextref="BasicHypercube_cfwd_30_09_2023_Set1" decimals="0" format="ixt2:numdotdecimal" name="ns5:IntangibleAssets" scale="0" unitref="GBP">181,671</ix:nonfraction>
# temp list: ['181,671', '118,757', '110,263', '71,408', '181,671']
# item: <ix:nonfraction contextref="Intangibles-SegmentsHypercube_cfwd_30_09_2022_Set5" decimals="0" format="ixt2:numdotdecimal" name="ns5:IntangibleAssets" scale="0" unitref="GBP">115,858</ix:nonfraction>
# temp list: ['181,671', '118,757', '110,263', '71,408', '181,671', '115,858']
# item: <ix:nonfraction contextref="Intangibles-SegmentsHypercube_cfwd_30_09_2022_Set6" decimals="0" format="ixt2:numdotdecimal" name="ns5:IntangibleAssets" scale="0" unitref="GBP">2,899</ix:nonfraction>
# temp list: ['181,671', '118,757', '110,263', '71,408', '181,671', '115,858', '2,899']
# item: <ix:nonfraction contextref="Intangibles-SegmentsHypercube_cfwd_30_09_2022_Set1" decimals="0" format="ixt2:numdotdecimal" name="ns5:IntangibleAssets" scale="0" unitref="GBP">118,757</ix:nonfraction>
# temp list: ['181,671', '118,757', '110,263', '71,408', '181,671', '115,858', '2,899', '118,757']
# label: PropertyPlantEquipment
# item: <ix:nonfraction contextref="BasicHypercube_cfwd_30_09_2023_Set1" decimals="0" format="ixt2:numdotdecimal" name="ns5:PropertyPlantEquipment" scale="0" unitref="GBP">891,769</ix:nonfraction>
# temp list: ['891,769']
# item: <ix:nonfraction contextref="Intangibles-SegmentsHypercube_cfwd_30_09_2022_Set1" decimals="0" format="ixt2:numdotdecimal" name="ns5:PropertyPlantEquipment" scale="0" unitref="GBP">870,538</ix:nonfraction>
# temp list: ['891,769', '870,538']
# item: <ix:nonfraction contextref="PPE-SegmentsHypercube_cfwd_30_09_2023_Set7" decimals="0" format="ixt2:zerodash" name="ns5:PropertyPlantEquipment" scale="0" unitref="GBP">-</ix:nonfraction>
# temp list: ['891,769', '870,538', '-']
# item: <ix:nonfraction contextref="PPE-SegmentsHypercube_cfwd_30_09_2023_Set8" decimals="0" format="ixt2:numdotdecimal" name="ns5:PropertyPlantEquipment" scale="0" unitref="GBP">871,426</ix:nonfraction>
# temp list: ['891,769', '870,538', '-', '871,426']
# item: <ix:nonfraction contextref="PPE-SegmentsHypercube_cfwd_30_09_2023_Set9" decimals="0" format="ixt2:numdotdecimal" name="ns5:PropertyPlantEquipment" scale="0" unitref="GBP">17,320</ix:nonfraction>
# temp list: ['891,769', '870,538', '-', '871,426', '17,320']
# item: <ix:nonfraction contextref="PPE-SegmentsHypercube_cfwd_30_09_2023_Set10" decimals="0" format="ixt2:numdotdecimal" name="ns5:PropertyPlantEquipment" scale="0" unitref="GBP">3,023</ix:nonfraction>
# temp list: ['891,769', '870,538', '-', '871,426', '17,320', '3,023']
# item: <ix:nonfraction contextref="BasicHypercube_cfwd_30_09_2023_Set1" decimals="0" format="ixt2:numdotdecimal" name="ns5:PropertyPlantEquipment" scale="0" unitref="GBP">891,769</ix:nonfraction>
# temp list: ['891,769', '870,538', '-', '871,426', '17,320', '3,023', '891,769']
# item: <ix:nonfraction contextref="PPE-SegmentsHypercube_cfwd_30_09_2022_Set7" decimals="0" format="ixt2:zerodash" name="ns5:PropertyPlantEquipment" scale="0" unitref="GBP">-</ix:nonfraction>
# temp list: ['891,769', '870,538', '-', '871,426', '17,320', '3,023', '891,769', '-']
# item: <ix:nonfraction contextref="PPE-SegmentsHypercube_cfwd_30_09_2022_Set8" decimals="0" format="ixt2:numdotdecimal" name="ns5:PropertyPlantEquipment" scale="0" unitref="GBP">831,251</ix:nonfraction>
# temp list: ['891,769', '870,538', '-', '871,426', '17,320', '3,023', '891,769', '-', '831,251']
# item: <ix:nonfraction contextref="PPE-SegmentsHypercube_cfwd_30_09_2022_Set9" decimals="0" format="ixt2:numdotdecimal" name="ns5:PropertyPlantEquipment" scale="0" unitref="GBP">32,966</ix:nonfraction>
# temp list: ['891,769', '870,538', '-', '871,426', '17,320', '3,023', '891,769', '-', '831,251', '32,966']
# item: <ix:nonfraction contextref="PPE-SegmentsHypercube_cfwd_30_09_2022_Set10" decimals="0" format="ixt2:numdotdecimal" name="ns5:PropertyPlantEquipment" scale="0" unitref="GBP">6,321</ix:nonfraction>
# temp list: ['891,769', '870,538', '-', '871,426', '17,320', '3,023', '891,769', '-', '831,251', '32,966', '6,321']
# item: <ix:nonfraction contextref="Intangibles-SegmentsHypercube_cfwd_30_09_2022_Set1" decimals="0" format="ixt2:numdotdecimal" name="ns5:PropertyPlantEquipment" scale="0" unitref="GBP">870,538</ix:nonfraction>
# temp list: ['891,769', '870,538', '-', '871,426', '17,320', '3,023', '891,769', '-', '831,251', '32,966', '6,321', '870,538']
# label: InvestmentsFixedAssets
# label: InvestmentsInGroupUndertakings
# label: LoansToGroupUndertakings
# label: InvestmentsInAssociatesJointVenturesParticipatingInterests
# label: LoansToAssociatesJointVenturesParticipatingInterests
# label: OtherInvestmentsOtherThanLoans
# label: OtherLoansClassifiedUnderInvestments
# label: OwnShares
# label: InvestmentProperty
# label: BiologicalAssetsNon-current
# label: CurrentAssets
# item: <ix:nonfraction contextref="BasicHypercube_cfwd_30_09_2023_Set1" decimals="0" format="ixt2:numdotdecimal" name="ns5:CurrentAssets" scale="0" unitref="GBP">7,515,231</ix:nonfraction>
# temp list: ['7,515,231']
# item: <ix:nonfraction contextref="Intangibles-SegmentsHypercube_cfwd_30_09_2022_Set1" decimals="0" format="ixt2:numdotdecimal" name="ns5:CurrentAssets" scale="0" unitref="GBP">6,525,810</ix:nonfraction>
# temp list: ['7,515,231', '6,525,810']
# label: TotalInventories
# item: <ix:nonfraction contextref="BasicHypercube_cfwd_30_09_2023_Set1" decimals="0" format="ixt2:numdotdecimal" name="ns5:TotalInventories" scale="0" unitref="GBP">1,055,860</ix:nonfraction>
# temp list: ['1,055,860']
# item: <ix:nonfraction contextref="Intangibles-SegmentsHypercube_cfwd_30_09_2022_Set1" decimals="0" format="ixt2:numdotdecimal" name="ns5:TotalInventories" scale="0" unitref="GBP">710,647</ix:nonfraction>
# temp list: ['1,055,860', '710,647']
# item: <ix:nonfraction contextref="BasicHypercube_cfwd_30_09_2023_Set1" decimals="0" format="ixt2:numdotdecimal" name="ns5:TotalInventories" scale="0" unitref="GBP">1,055,860</ix:nonfraction>
# temp list: ['1,055,860', '710,647', '1,055,860']
# item: <ix:nonfraction contextref="Intangibles-SegmentsHypercube_cfwd_30_09_2022_Set1" decimals="0" format="ixt2:numdotdecimal" name="ns5:TotalInventories" scale="0" unitref="GBP">710,647</ix:nonfraction>
# temp list: ['1,055,860', '710,647', '1,055,860', '710,647']
# label: BiologicalAssetsCurrent
# label: Debtors
# item: <ix:nonfraction contextref="BasicHypercube_cfwd_30_09_2023_Set1" decimals="0" format="ixt2:numdotdecimal" name="ns5:Debtors" scale="0" unitref="GBP">2,564,830</ix:nonfraction>
# temp list: ['2,564,830']
# item: <ix:nonfraction contextref="Intangibles-SegmentsHypercube_cfwd_30_09_2022_Set1" decimals="0" format="ixt2:numdotdecimal" name="ns5:Debtors" scale="0" unitref="GBP">1,941,001</ix:nonfraction>
# temp list: ['2,564,830', '1,941,001']
# item: <ix:nonfraction contextref="DebtorsHypercube_cfwd_30_09_2023_Set11" decimals="0" format="ixt2:numdotdecimal" name="ns5:Debtors" scale="0" unitref="GBP">2,564,830</ix:nonfraction>
# temp list: ['2,564,830', '1,941,001', '2,564,830']
# item: <ix:nonfraction contextref="DebtorsHypercube_cfwd_30_09_2022_Set11" decimals="0" format="ixt2:numdotdecimal" name="ns5:Debtors" scale="0" unitref="GBP">1,941,001</ix:nonfraction>
# temp list: ['2,564,830', '1,941,001', '2,564,830', '1,941,001']
# label: TradeDebtorsTradeReceivables
# item: <ix:nonfraction contextref="CreditorsHypercube_cfwd_30_09_2023_Set2" decimals="0" format="ixt2:numdotdecimal" name="ns5:TradeDebtorsTradeReceivables" scale="0" unitref="GBP">2,447,632</ix:nonfraction>
# temp list: ['2,447,632']
# item: <ix:nonfraction contextref="CreditorsHypercube_cfwd_30_09_2022_Set2" decimals="0" format="ixt2:numdotdecimal" name="ns5:TradeDebtorsTradeReceivables" scale="0" unitref="GBP">1,874,762</ix:nonfraction>
# temp list: ['2,447,632', '1,874,762']
# label: AmountsOwedByGroupUndertakings
# label: AmountsOwedByAssociatesJointVenturesParticipatingInterests
# label: OtherDebtorsBalanceSheetSubtotal
# label: CalledUpShareCapitalNotPaidCurrentAsset
# label: PrepaymentsAccruedIncome
# item: <ix:nonfraction contextref="CreditorsHypercube_cfwd_30_09_2023_Set2" decimals="0" format="ixt2:numdotdecimal" name="ns5:PrepaymentsAccruedIncome" scale="0" unitref="GBP">58,101</ix:nonfraction>
# temp list: ['58,101']
# item: <ix:nonfraction contextref="CreditorsHypercube_cfwd_30_09_2022_Set2" decimals="0" format="ixt2:numdotdecimal" name="ns5:PrepaymentsAccruedIncome" scale="0" unitref="GBP">66,239</ix:nonfraction>
# temp list: ['58,101', '66,239']
# label: DeferredTaxAssetDebtors
# label: CurrentAssetInvestments
# label: InvestmentsInGroupUndertakings
# label: OwnShares
# label: OtherCurrentAssetInvestmentsBalanceSheetSubtotal
# label: CashBankOnHand
# item: <ix:nonfraction contextref="BasicHypercube_cfwd_30_09_2023_Set1" decimals="0" format="ixt2:numdotdecimal" name="ns5:CashBankOnHand" scale="0" unitref="GBP">3,894,541</ix:nonfraction>
# temp list: ['3,894,541']
# item: <ix:nonfraction contextref="Intangibles-SegmentsHypercube_cfwd_30_09_2022_Set1" decimals="0" format="ixt2:numdotdecimal" name="ns5:CashBankOnHand" scale="0" unitref="GBP">3,874,162</ix:nonfraction>
# temp list: ['3,894,541', '3,874,162']
# label: AverageNumberEmployeesDuringPeriod
# item: <ix:nonfraction contextref="BasicHypercube_FY_30_09_2023_Set4" decimals="INF" name="ns5:AverageNumberEmployeesDuringPeriod" scale="0" unitref="pure">78</ix:nonfraction>
# temp list: ['78']
# item: <ix:nonfraction contextref="Income-MainHypercube_FY_30_09_2022_Set1" decimals="INF" name="ns5:AverageNumberEmployeesDuringPeriod" scale="0" unitref="pure">87</ix:nonfraction>
# temp list: ['78', '87']
# ----------------------------------------------------------------------
# Turnover Revenue:                   ['11,351,248', '10,813,162']
# Fixed Assets:                       ['1,073,440', '989,295']
# Current Assets:                     ['7,515,231', '6,525,810']
# Average Number Employees | Period:  ['78', '87']
# Balance Sheet Total:                ['8,588,671', '7,515,105']
# ----------------------------------------------------------------------
# Size of Entity: Medium
# Company: WALLGATE LIMITED, Size: medium
# ####################################################################################################
#
# Processing company: ARVINMERITOR LIGHT VEHICLE SYSTEMS (UK) LIMITED (ID: 00219220)
# Retrieved filling history for ARVINMERITOR LIGHT VEHICLE SYSTEMS (UK) LIMITED
# Found 7 'AA' type items for ARVINMERITOR LIGHT VEHICLE SYSTEMS (UK) LIMITED
# XHTML document found for ARVINMERITOR LIGHT VEHICLE SYSTEMS (UK) LIMITED
# Retrieved document URL for ARVINMERITOR LIGHT VEHICLE SYSTEMS (UK) LIMITED
# Retrieved JSON object for ARVINMERITOR LIGHT VEHICLE SYSTEMS (UK) LIMITED
# Retrieved XHTML document for ARVINMERITOR LIGHT VEHICLE SYSTEMS (UK) LIMITED
# Saved XHTML file for ARVINMERITOR LIGHT VEHICLE SYSTEMS (UK) LIMITED
# Classifying size for ARVINMERITOR LIGHT VEHICLE SYSTEMS (UK) LIMITED...
# label: TurnoverRevenue
# label: FixedAssets
# label: IntangibleAssets
# label: PropertyPlantEquipment
# label: InvestmentsFixedAssets
# label: InvestmentsInGroupUndertakings
# label: LoansToGroupUndertakings
# label: InvestmentsInAssociatesJointVenturesParticipatingInterests
# label: LoansToAssociatesJointVenturesParticipatingInterests
# label: OtherInvestmentsOtherThanLoans
# label: OtherLoansClassifiedUnderInvestments
# label: OwnShares
# label: InvestmentProperty
# label: BiologicalAssetsNon-current
# label: CurrentAssets
# label: TotalInventories
# label: BiologicalAssetsCurrent
# label: Debtors
# item: <ix:nonfraction contextref="B" decimals="-3" format="ixt:numcommadot" name="core:Debtors" scale="3" unitref="GBP">8,922</ix:nonfraction>
# temp list: ['8,922,000']
# item: <ix:nonfraction contextref="E" decimals="-3" format="ixt:numcommadot" name="core:Debtors" scale="3" unitref="GBP">8,922</ix:nonfraction>
# temp list: ['8,922,000', '8,922,000']
# label: TradeDebtorsTradeReceivables
# label: AmountsOwedByGroupUndertakings
# label: AmountsOwedByAssociatesJointVenturesParticipatingInterests
# label: OtherDebtorsBalanceSheetSubtotal
# label: CalledUpShareCapitalNotPaidCurrentAsset
# label: PrepaymentsAccruedIncome
# label: DeferredTaxAssetDebtors
# label: CurrentAssetInvestments
# label: InvestmentsInGroupUndertakings
# label: OwnShares
# label: OtherCurrentAssetInvestmentsBalanceSheetSubtotal
# label: CashBankOnHand
# label: AverageNumberEmployeesDuringPeriod
# item: <ix:nonfraction contextref="C" decimals="INF" format="ixt:numcommadot" name="core:AverageNumberEmployeesDuringPeriod" unitref="Pure">0</ix:nonfraction>
# temp list: ['0']
# item: <ix:nonfraction contextref="F" decimals="INF" format="ixt:numcommadot" name="core:AverageNumberEmployeesDuringPeriod" unitref="Pure">0</ix:nonfraction>
# temp list: ['0', '0']
# TurnoverRevenue list is empty.
# attempting to match Turnover
# Could not find 'Turnover' tag
# FixedAssets list is empty.
# CurrentAssets list is empty.
# Investment Fixed Assets value was missing and calculated using components.
# Fixed Assets value was missing and calculated using components.
# Current Asset Investments value was missing and calculated using components.
# Current Assets value was missing and calculated using components.
# ----------------------------------------------------------------------
# Turnover Revenue:                   []
# Fixed Assets:                       ['0', '0']
# Current Assets:                     ['8,922,000', '8,922,000']
# Average Number Employees | Period:  ['0', '0']
# Balance Sheet Total:                ['8,922,000', '8,922,000']
# ----------------------------------------------------------------------
# Size of Entity: Medium
# Company: ARVINMERITOR LIGHT VEHICLE SYSTEMS (UK) LIMITED, Size: medium
#
# Finished processing all companies.
# Added size data to dataframe.

# %% [markdown]
# # Save results to CSV
#
# A spreadsheet with evaluations results and notes can be found here:
# https://docs.google.com/spreadsheets/d/1aMZyXyjDJWzqOB2Jste8AaunHuYLa6t9uy1VnB81g5c/edit?gid=0#gid=0

# %%
# Save data_ixbrl to CSV with timestamp
import datetime

# Get current timestamp in human-readable format
timestamp = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")

# Create filename with timestamp
filename = f"csv/results_data_ixbrl_{timestamp}.csv"

# Save DataFrame to CSV
data_ixbrl.to_csv(filename, index=False)

print(f"Data saved to {filename}")

# Display the DataFrame
data_ixbrl
# Out:
# Data saved to csv/results_data_ixbrl_2024-07-04_11-53-01.csv
#     company_number                                       company_name  ixbrl  \
# 7            11717  ULVERSTON AUCTION MART PUBLIC LIMITED COMPANY(...      1
# 15         1024277                                  TOTAL SYSTEMS PLC      1
# 19          737075                                   SANDUSKY LIMITED      1
# 20          277871                                ALAN HADLEY LIMITED      1
# 23         2847809                   NORSK EUROPEAN WHOLESALE LIMITED      1
# 27          114709                                 J F ASHTON LIMITED      1
# 30         1349434                                        PSD LIMITED      1
# 31          335313                    COLE & SON (WALLPAPERS) LIMITED      1
# 33          650255                                TORPEDO FACTORY LTD      1
# 34          865285                                     VISTRA LIMITED      1
# 37         1053218                                     TECHEX LIMITED      1
# 48         1130989                           W.T. PARTNERSHIP LIMITED      1
# 49         1185121                   BUTTERWORTH LABORATORIES LIMITED      1
# 58          293103                        W.A. TRUELOVE & SON LIMITED      1
# 61          408782               PRITCHARD PATENT PRODUCT CO. LIMITED      1
# 66          707744                    WILKES VENDING SERVICES LIMITED      1
# 67          762224                        H.G.BLAKE(COSTESSEY)LIMITED      1
# 69          777567                          DOVESTONE ESTATES LIMITED      1
# 74          872451                        P. & F. SAFEPAC CO. LIMITED      1
# 75         1041096                           HAMILTON RENTALS LIMITED      1
# 82         1486255                                       HTEC LIMITED      1
# 83         1500217                                 ATEX MEDIA LIMITED      1
# 84          159161                     PALMERS SCAFFOLDING UK LIMITED      1
# 85          196308        P.C.RICHARDSON & CO.(MIDDLESBROUGH),LIMITED      1
# 86          236372                      COLLINS (CONTRACTORS) LIMITED      1
# 88           43081                             LOAKE BROTHERS LIMITED      1
# 89           66706                        ARIGHI BIANCHI & CO.LIMITED      1
# 96           66471                               G.B. KENT & SONS PLC      1
# 97          156022                                   WALLGATE LIMITED      1
# 98          219220    ARVINMERITOR LIGHT VEHICLE SYSTEMS (UK) LIMITED      1
#
#       size size evals
# 7    small      small
# 15   small      small
# 19   small      small
# 20   small      small
# 23  medium     medium
# 27  medium     medium
# 30  medium     medium
# 31  medium     medium
# 33   small      small
# 34   small      small
# 37  medium     medium
# 48  medium     medium
# 49  medium     medium
# 58  medium     medium
# 61  medium     medium
# 66  medium     medium
# 67  medium     medium
# 69  medium     medium
# 74  medium     medium
# 75  medium     medium
# 82  medium     medium
# 83   small      small
# 84  medium     medium
# 85  medium     medium
# 86  medium     medium
# 88  medium     medium
# 89  medium     medium
# 96  medium      small
# 97  medium     medium
# 98   small     medium
